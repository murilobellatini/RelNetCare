# %%
import json
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
from src.paths import LOCAL_PROCESSED_DATA_PATH

# %%
from src.paths import LOCAL_PROCESSED_DATA_PATH
from src.processing.etl import DialogREDatasetTransformer
from src.processing.ner import EntityProcessor
from src.processing.utils import get_counts_and_percentages


dt = DialogREDatasetTransformer(LOCAL_PROCESSED_DATA_PATH / 'dialog-re-binary-enriched')
df = dt.load_data_to_dataframe()

# %%
df_relations = df.explode('Relations').apply(lambda r: {**{"Origin": r['Origin'], 'Dialogue': r['Dialogue']}, **r['Relations']}, axis=1)
df_relations = pd.json_normalize(df_relations)
df_relations.head(3).T
# Out:
#                                                                         0  \
# Origin                                                                dev
# Dialogue                [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# y                                                        casting director
# x                                                                     Ann
# rid                                                                   [1]
# r                                                         [with_relation]
# t                                                                      []
# x_type                                                                PER
# y_type                                                             STRING
# x_token_span                                                   [269, 313]
# y_token_span                                                   [391, 392]
# x_char_span                                                   [966, 1154]
# y_char_span                                                  [1430, 1433]
# min_words_distance                                                   81.0
# min_words_distance_pct                                           0.038553
# connecting_text         casting director told her that I missed my cha...
# min_turn_distance                                                     3.0
# min_turn_distance_pct                                            0.001428
# spacy_features.x_pos                                                 VERB
# spacy_features.x_dep                                                 amod
# spacy_features.x_tag                                                  VBG
# spacy_features.y_pos                                                PROPN
# spacy_features.y_dep                                             npadvmod
# spacy_features.y_tag                                                  NNP
#
#                                                                         1  \
# Origin                                                                dev
# Dialogue                [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# y                                                                   Annie
# x                                                                     Ann
# rid                                                                   [1]
# r                                                         [with_relation]
# t                                                                      []
# x_type                                                                PER
# y_type                                                                PER
# x_token_span                                                   [391, 392]
# y_token_span                                                   [418, 522]
# x_char_span                                                  [1430, 1433]
# y_char_span                                                  [1523, 1941]
# min_words_distance                                                   26.0
# min_words_distance_pct                                           0.012375
# connecting_text         Ann there for Phoebe, she'll know what it's ab...
# min_turn_distance                                                     0.0
# min_turn_distance_pct                                                 0.0
# spacy_features.x_pos                                                PROPN
# spacy_features.x_dep                                             npadvmod
# spacy_features.x_tag                                                  NNP
# spacy_features.y_pos                                                PROPN
# spacy_features.y_dep                                             npadvmod
# spacy_features.y_tag                                                  NNP
#
#                                                                         2
# Origin                                                                dev
# Dialogue                [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# y                                                                   agent
# x                                                                 Estelle
# rid                                                                   [1]
# r                                                         [with_relation]
# t                                                                      []
# x_type                                                                PER
# y_type                                                             STRING
# x_token_span                                                     [31, 32]
# y_token_span                                                   [262, 515]
# x_char_span                                                    [101, 106]
# y_char_span                                                   [937, 1920]
# min_words_distance                                                  232.0
# min_words_distance_pct                                           0.110424
# connecting_text         agent would like to know why I didn't show up ...
# min_turn_distance                                                     2.0
# min_turn_distance_pct                                            0.000952
# spacy_features.x_pos                                                 NOUN
# spacy_features.x_dep                                                nsubj
# spacy_features.x_tag                                                   NN
# spacy_features.y_pos                                                PROPN
# spacy_features.y_dep                                                 pobj
# spacy_features.y_tag                                                  NNP

# %%
df_relations['r'].value_counts()
# Out:
# [no_relation_unanswerable]    18588
# [with_relation]                7650
# Name: r, dtype: int64

# %%
df_relations = df_relations.dropna()  # Filling with -1 or another value that does not interfere with your data
# If 'r' is a list, extract the first element
df_relations['r'] = df_relations['r'].str[0]

# Encode your target variable 'r' if it is categorical
le = LabelEncoder()
df_relations['r'] = le.fit_transform(df_relations['r'])

# %%
df_relations[col].value_counts()
# Out:
# PROPN    20192
# NOUN      4133
# ADJ        158
# PRON        88
# NUM         66
# VERB        55
# DET         51
# INTJ        27
# AUX         15
# X           13
# ADP          8
# ADV          6
# PUNCT        1
# Name: spacy_features.x_pos, dtype: int64

# %%
for col in ['x_type', 'y_type', 'spacy_features.x_pos', 'spacy_features.x_dep', 'spacy_features.x_tag', 'spacy_features.y_pos', 'spacy_features.y_dep', 'spacy_features.y_tag']:
    df_relations[col] = LabelEncoder().fit_transform(df_relations[col])
# Out:
# x_type
# y_type
# spacy_features.x_pos
# spacy_features.x_dep
# spacy_features.x_tag
# spacy_features.y_pos
# spacy_features.y_dep
# spacy_features.y_tag

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the `TfidfVectorizer`
vectorizer = TfidfVectorizer(max_features=1000)  # Adjust the max_features parameter to your need

# Fit and transform the `connecting_text` column 
TFIDF = vectorizer.fit_transform(df_relations['connecting_text']).toarray()

# Now, TFIDF is a numerical matrix representing your text data that you can use as input to your model

# %%
# Convert TF-IDF to DataFrame
tfidf_df = pd.DataFrame(TFIDF, columns=vectorizer.get_feature_names_out())

# %%
# Merge the DataFrames
df_relations = pd.concat([df_relations.reset_index(drop=True), tfidf_df.reset_index(drop=True)], axis=1)

# %%
df_relations.head(3).T.head(30)
# Out:
#                                                                         0  \
# Origin                                                                dev
# Dialogue                [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# y                                                        casting director
# x                                                                     Ann
# rid                                                                   [1]
# r                                                                       1
# t                                                                      []
# x_type                                                                  2
# y_type                                                                  3
# x_token_span                                                   [269, 313]
# y_token_span                                                   [391, 392]
# x_char_span                                                   [966, 1154]
# y_char_span                                                  [1430, 1433]
# min_words_distance                                                   81.0
# min_words_distance_pct                                           0.038553
# connecting_text         casting director told her that I missed my cha...
# min_turn_distance                                                     3.0
# min_turn_distance_pct                                            0.001428
# spacy_features.x_pos                                                   11
# spacy_features.x_dep                                                    4
# spacy_features.x_tag                                                   20
# spacy_features.y_pos                                                    9
# spacy_features.y_dep                                                   17
# spacy_features.y_tag                                                    9
# 10                                                                    0.0
# 20                                                                    0.0
# 25                                                                    0.0
# 30                                                                    0.0
# 50                                                                    0.0
# able                                                                  0.0
#
#                                                                         1  \
# Origin                                                                dev
# Dialogue                [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# y                                                                   Annie
# x                                                                     Ann
# rid                                                                   [1]
# r                                                                       1
# t                                                                      []
# x_type                                                                  2
# y_type                                                                  2
# x_token_span                                                   [391, 392]
# y_token_span                                                   [418, 522]
# x_char_span                                                  [1430, 1433]
# y_char_span                                                  [1523, 1941]
# min_words_distance                                                   26.0
# min_words_distance_pct                                           0.012375
# connecting_text         Ann there for Phoebe, she'll know what it's ab...
# min_turn_distance                                                     0.0
# min_turn_distance_pct                                                 0.0
# spacy_features.x_pos                                                    9
# spacy_features.x_dep                                                   18
# spacy_features.x_tag                                                   10
# spacy_features.y_pos                                                    9
# spacy_features.y_dep                                                   17
# spacy_features.y_tag                                                    9
# 10                                                                    0.0
# 20                                                                    0.0
# 25                                                                    0.0
# 30                                                                    0.0
# 50                                                                    0.0
# able                                                                  0.0
#
#                                                                         2
# Origin                                                                dev
# Dialogue                [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# y                                                                   agent
# x                                                                 Estelle
# rid                                                                   [1]
# r                                                                       1
# t                                                                      []
# x_type                                                                  2
# y_type                                                                  3
# x_token_span                                                     [31, 32]
# y_token_span                                                   [262, 515]
# x_char_span                                                    [101, 106]
# y_char_span                                                   [937, 1920]
# min_words_distance                                                  232.0
# min_words_distance_pct                                           0.110424
# connecting_text         agent would like to know why I didn't show up ...
# min_turn_distance                                                     2.0
# min_turn_distance_pct                                            0.000952
# spacy_features.x_pos                                                    6
# spacy_features.x_dep                                                   19
# spacy_features.x_tag                                                    9
# spacy_features.y_pos                                                    9
# spacy_features.y_dep                                                   24
# spacy_features.y_tag                                                    9
# 10                                                               0.071083
# 20                                                                    0.0
# 25                                                                    0.0
# 30                                                                    0.0
# 50                                                                    0.0
# able                                                                  0.0

# %%
df_relations['x_token_span_start'] = df_relations.x_token_span.apply(lambda x: x[0])
df_relations['x_token_span_end'] = df_relations.x_token_span.apply(lambda x: x[1])
df_relations['y_token_span_start'] = df_relations.y_token_span.apply(lambda x: x[0])
df_relations['y_token_span_end'] = df_relations.y_token_span.apply(lambda x: x[1])

# %%
# Out:
#        x_type  y_type  min_words_distance  min_words_distance_pct  \
# 9841        2       2               101.0                0.088287
# 9842        2       2                13.0                0.011364
# 9843        2       2                 6.0                0.005245
# 9844        2       2                19.0                0.016608
# 9845        2       2                12.0                0.010490
# ...       ...     ...                 ...                     ...
# 24808       2       2                 3.0                0.006772
# 24809       2       2                 2.0                0.004515
# 24810       2       2                63.0                0.142212
# 24811       2       2                 3.0                0.006772
# 24812       2       2                57.0                0.128668
#
#        min_turn_distance  min_turn_distance_pct  spacy_features.x_pos  \
# 9841                 5.0               0.004371                     9
# 9842                 1.0               0.000874                     9
# 9843                 1.0               0.000874                     9
# 9844                 1.0               0.000874                     9
# 9845                 0.0               0.000000                     9
# ...                  ...                    ...                   ...
# 24808                0.0               0.000000                     6
# 24809                0.0               0.000000                     9
# 24810                5.0               0.011287                     6
# 24811                0.0               0.000000                     9
# 24812                4.0               0.009029                     6
#
#        spacy_features.x_dep  spacy_features.x_tag  spacy_features.y_pos  ...  \
# 9841                     18                    10                     9  ...
# 9842                     18                    10                     9  ...
# 9843                     18                    10                     7  ...
# 9844                     18                    10                     9  ...
# 9845                     18                    10                     9  ...
# ...                     ...                   ...                   ...  ...
# 24808                     0                     9                     9  ...
# 24809                    19                    10                     7  ...
# 24810                     0                     9                     7  ...
# 24811                    19                    10                     9  ...
# 24812                     0                     9                     9  ...
#
#        york       you  young      your  yours  yourself  x_token_span_start  \
# 9841    0.0  0.238864    0.0  0.130467    0.0       0.0                   0
# 9842    0.0  0.180182    0.0  0.000000    0.0       0.0                  35
# 9843    0.0  0.246783    0.0  0.134792    0.0       0.0                  35
# 9844    0.0  0.213271    0.0  0.166412    0.0       0.0                  88
# 9845    0.0  0.048700    0.0  0.177334    0.0       0.0                  88
# ...     ...       ...    ...       ...    ...       ...                 ...
# 24808   0.0  0.167362    0.0  0.000000    0.0       0.0                   0
# 24809   0.0  0.153144    0.0  0.000000    0.0       0.0                   9
# 24810   0.0  0.175216    0.0  0.000000    0.0       0.0                   0
# 24811   0.0  0.175512    0.0  0.000000    0.0       0.0                   9
# 24812   0.0  0.162131    0.0  0.000000    0.0       0.0                   0
#
#        x_token_span_end  y_token_span_start  y_token_span_end
# 9841                176                 277               278
# 9842                306                  95                97
# 9843                306                  88               296
# 9844                296                 277               278
# 9845                296                 102               173
# ...                 ...                 ...               ...
# 24808                26                  29                43
# 24809               107                   9               107
# 24810                26                  85                87
# 24811               107                  29                43
# 24812                26                  83                89
#
# [14972 rows x 1016 columns]

# %%
# Define your datasets based on 'Origin'
cols = list(set(['min_turn_distance', 'min_words_distance', 'y_type', 'x_type', 'x_token_span_start', 'x_token_span_end', 'y_token_span_start', 'y_token_span_end', 'spacy_features.y_tag', 'spacy_features.x_tag', 'min_turn_distance_pct', 'x_token_span_end']))
train_data = df_relations[df_relations['Origin'] == 'train']
test_data = df_relations[df_relations['Origin'] == 'test']
dev_data = df_relations[df_relations['Origin'] == 'dev']

# Drop the 'Origin', 'Dialogue', and 'connecting_text' columns for each dataset
X_train = train_data.drop(['x', 'y','Origin', 'Dialogue', 'r', 'connecting_text', 'rid', 't', 'x_token_span', 'y_token_span', 'x_char_span', 'y_char_span'], axis=1)[cols]
X_test = test_data.drop(['x', 'y','Origin', 'Dialogue', 'r', 'connecting_text', 'rid', 't', 'x_token_span', 'y_token_span', 'x_char_span', 'y_char_span'], axis=1)[cols]
X_dev = dev_data.drop(['x', 'y','Origin', 'Dialogue', 'r', 'connecting_text', 'rid', 't', 'x_token_span', 'y_token_span', 'x_char_span', 'y_char_span'], axis=1)[cols]

# Define the target for each dataset
y_train = train_data['r']
y_test = test_data['r']
y_dev = dev_data['r']

# Create XGBoost matrices for each dataset
D_train = xgb.DMatrix(X_train, label=y_train)
D_test = xgb.DMatrix(X_test, label=y_test)
D_dev = xgb.DMatrix(X_dev, label=y_dev)


# Define your XGBoost parameters
xgb_params = {
    'eta': 0.5, 
    'max_depth': 3,  
    # 'scale_pos_weight':  df_relations['r'].value_counts()[0] / df_relations['r'].value_counts()[1],
    # 'objective': 'binary:logistic',  # change this to binary:logistic
    'objective': 'multi:softprob',  
    'num_class': 2,  # Modify this depending on the number of classes in 'r'
}


# Train the model on training data
model = xgb.train(xgb_params, D_train, num_boost_round=20)

# Make predictions on test and dev data
preds_test = model.predict(D_test)
preds_dev = model.predict(D_dev)

# Convert predictions to np arrays
best_preds_test = np.asarray([np.argmax(line) for line in preds_test])
best_preds_dev = np.asarray([np.argmax(line) for line in preds_dev])

# Check accuracy
print("Test Accuracy = ", accuracy_score(y_test, best_preds_test))
print("Dev Accuracy = ", accuracy_score(y_dev, best_preds_dev))

# Classification reports
print("Test Classification Report:")
print(classification_report(y_test, best_preds_test))

print("Dev Classification Report:")
print(classification_report(y_dev, best_preds_dev))
# Out:
# Test Accuracy =  0.7389591540534937
# Dev Accuracy =  0.7220007971303308
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83      3416
#            1       0.58      0.38      0.46      1407
#
#     accuracy                           0.74      4823
#    macro avg       0.68      0.63      0.64      4823
# weighted avg       0.72      0.74      0.72      4823
#
# Dev Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81      3550
#            1       0.53      0.40      0.45      1468
#
#     accuracy                           0.72      5018
#    macro avg       0.65      0.63      0.63      5018
# weighted avg       0.70      0.72      0.71      5018

# %%
# Get feature importance
feature_importance = model.get_score(importance_type='gain')

# Convert it to a DataFrame
feature_importance = pd.DataFrame(list(feature_importance.items()), columns=['Feature','Score'])

# Sort the DataFrame by importance score
feature_importance = feature_importance.sort_values(by='Score', ascending=False)

feature_importance.head(20)
# Out:
#                   Feature      Score
# 7       min_turn_distance  62.332779
# 0                  y_type  36.443806
# 6      min_words_distance  35.241142
# 1      x_token_span_start  16.399227
# 3   min_turn_distance_pct  10.143242
# 4      y_token_span_start   9.886332
# 8    spacy_features.y_tag   8.662965
# 9    spacy_features.x_tag   3.922575
# 5        y_token_span_end   3.592736
# 2        x_token_span_end   3.415333
# 10                 x_type   2.055440

# %%
min_turn_distance, y_type, min_words_distance

# %%
# This will extract the features from the "Relations" dictionary into separate columns
df_relations = pd.json_normalize(df['Relations'])

# Join the new DataFrame with the old one, keeping only the necessary columns
df = df.drop('Relations', axis=1).join(df_relations)

# %%
df
# Out:
#                                                Dialogue Origin  \
# 0     [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...    dev
# 1     [Speaker 1, Speaker 2: Hi, Speaker 3: Hi! Hey ...    dev
# 2     [Speaker 1, Speaker 2: Hi!, Speaker 3: Hey!, S...    dev
# 3     [Speaker 1: Wow! It looks like we got a lot of...    dev
# 4     [Speaker 1: Now, Mom, everything's going fine,...    dev
# ...                                                 ...    ...
# 1783  [Speaker 1: Nice camoflauge man, for a minute ...  train
# 1784  [Speaker 1: Well, I'm sure you'll teach her a ...  train
# 1785  [Speaker 1: You know what? I can't even worry ...  train
# 1786  [Speaker 1: And cut. Hey, Butt Guy, what the h...  train
# 1787  [Speaker 1: Buon Giorno, Bella Phoebe!, Speake...  train
#
#                                                       0  \
# 0     {'y': 'casting director', 'x': 'Ann', 'rid': [...
# 1     {'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [1...
# 2     {'y': 'man', 'x': 'Speaker 4', 'rid': [0], 'r'...
# 3     {'y': 'baby', 'x': 'Speaker 2', 'rid': [0], 'r...
# 4     {'y': '26', 'x': 'Speaker 1', 'rid': [1], 'r':...
# ...                                                 ...
# 1783  {'y': 'Speaker 1', 'x': 'Speaker 2', 'rid': [1...
# 1784  {'y': 'Sir', 'x': 'Speaker 1', 'rid': [0], 'r'...
# 1785  {'y': 'baby', 'x': 'Speaker 1', 'rid': [0], 'r...
# 1786  {'y': 'Butt Guy', 'x': 'Speaker 2', 'rid': [1]...
# 1787  {'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [1...
#
#                                                       1  \
# 0     {'y': 'Annie', 'x': 'Ann', 'rid': [1], 'r': ['...
# 1     {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [1...
# 2     {'y': 'one', 'x': 'Speaker 4', 'rid': [1], 'r'...
# 3     {'y': 'Speaker 3', 'x': 'Speaker 2', 'rid': [1...
# 4     {'y': 'Ross', 'x': 'Speaker 1', 'rid': [1], 'r...
# ...                                                 ...
# 1783  {'y': 'Susie Moss', 'x': 'Speaker 2', 'rid': [...
# 1784  {'y': 'Bing', 'x': 'Speaker 1', 'rid': [1], 'r...
# 1785  {'y': 'little girl', 'x': 'Speaker 1', 'rid': ...
# 1786                                               None
# 1787  {'y': 'Pheebs', 'x': 'Speaker 6', 'rid': [0], ...
#
#                                                       2  \
# 0     {'y': 'agent', 'x': 'Estelle', 'rid': [1], 'r'...
# 1     {'y': 'Speaker 1', 'x': 'Speaker 2', 'rid': [1...
# 2     {'y': 'Speaker 3', 'x': 'Emma', 'rid': [1], 'r...
# 3     {'y': 'roomie', 'x': 'Speaker 2', 'rid': [0], ...
# 4     {'y': 'Speaker 1', 'x': 'Ross', 'rid': [1], 'r...
# ...                                                 ...
# 1783  {'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [1...
# 1784  {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [1...
# 1785  {'y': 'Rach', 'x': 'Speaker 1', 'rid': [1], 'r...
# 1786                                               None
# 1787  {'y': 'Racquela', 'x': 'Speaker 6', 'rid': [1]...
#
#                                                       3  \
# 0     {'y': 'Speaker 1', 'x': 'Estelle', 'rid': [1],...
# 1     {'y': 'Speaker 3', 'x': 'Speaker 2', 'rid': [1...
# 2     {'y': 'one', 'x': 'Emma', 'rid': [1], 'r': ['w...
# 3     {'y': 'Speaker 2', 'x': 'Speaker 3', 'rid': [1...
# 4     {'y': '26', 'x': 'Ross', 'rid': [0], 'r': ['no...
# ...                                                 ...
# 1783  {'y': 'Chandler Bing', 'x': 'Speaker 1', 'rid'...
# 1784  {'y': 'sir', 'x': 'Speaker 3', 'rid': [1], 'r'...
# 1785  {'y': 'baby', 'x': 'Speaker 2', 'rid': [0], 'r...
# 1786                                               None
# 1787  {'y': 'Pheebs', 'x': 'Speaker 2', 'rid': [1], ...
#
#                                                       4  \
# 0     {'y': 'Katelynn', 'x': 'Speaker 2', 'rid': [1]...
# 1     {'y': 'Speaker 3', 'x': 'Jack', 'rid': [1], 'r...
# 2     {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': ...
# 3     {'y': 'roomie', 'x': 'Speaker 3', 'rid': [1], ...
# 4     {'y': 'Speaker 1', 'x': 'Speaker 1', 'rid': [0...
# ...                                                 ...
# 1783  {'y': 'man', 'x': 'Speaker 1', 'rid': [0], 'r'...
# 1784  {'y': 'Speaker 1', 'x': 'Speaker 3', 'rid': [1...
# 1785  {'y': 'Rach', 'x': 'Speaker 2', 'rid': [0], 'r...
# 1786                                               None
# 1787  {'y': 'Speaker 1', 'x': 'Speaker 2', 'rid': [1...
#
#                                                       5  \
# 0     {'y': 'Pheebs', 'x': 'Speaker 2', 'rid': [1], ...
# 1     {'y': 'Speaker 2', 'x': 'Speaker 3', 'rid': [1...
# 2     {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': ...
# 3     {'y': 'baby', 'x': 'Speaker 1', 'rid': [0], 'r...
# 4     {'y': 'Ross', 'x': 'Ross', 'rid': [0], 'r': ['...
# ...                                                 ...
# 1783  {'y': 'Susie Moss', 'x': 'Speaker 1', 'rid': [...
# 1784  {'y': 'sir', 'x': 'Speaker 1', 'rid': [0], 'r'...
# 1785  {'y': 'little girl', 'x': 'Speaker 2', 'rid': ...
# 1786                                               None
# 1787  {'y': 'Speaker 1', 'x': 'Speaker 1', 'rid': [0...
#
#                                                       6  \
# 0     {'y': 'Speaker 1', 'x': 'Speaker 2', 'rid': [1...
# 1     {'y': 'Speaker 1', 'x': 'Speaker 3', 'rid': [1...
# 2     {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': ...
# 3     {'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [0...
# 4                                                  None
# ...                                                 ...
# 1783  {'y': 'man', 'x': 'Speaker 2', 'rid': [0], 'r'...
# 1784  {'y': 'Sir', 'x': 'Speaker 3', 'rid': [0], 'r'...
# 1785                                               None
# 1786                                               None
# 1787  {'y': 'Speaker 2', 'x': 'Speaker 6', 'rid': [0...
#
#                                                       7  ...   130   131  \
# 0     {'y': 'Phoebe Buffay', 'x': 'Speaker 2', 'rid'...  ...  None  None
# 1     {'y': 'Jack', 'x': 'Speaker 3', 'rid': [1], 'r...  ...  None  None
# 2     {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': ...  ...  None  None
# 3     {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0...  ...  None  None
# 4                                                  None  ...  None  None
# ...                                                 ...  ...   ...   ...
# 1783  {'y': 'Chandler Bing', 'x': 'Speaker 2', 'rid'...  ...  None  None
# 1784  {'y': 'Speaker 3', 'x': 'Speaker 3', 'rid': [0...  ...  None  None
# 1785                                               None  ...  None  None
# 1786                                               None  ...  None  None
# 1787  {'y': 'Racquela', 'x': 'Speaker 1', 'rid': [0]...  ...  None  None
#
#        132   133   134   135   136   137   138   139
# 0     None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 1783  None  None  None  None  None  None  None  None
# 1784  None  None  None  None  None  None  None  None
# 1785  None  None  None  None  None  None  None  None
# 1786  None  None  None  None  None  None  None  None
# 1787  None  None  None  None  None  None  None  None
#
# [1788 rows x 142 columns]

# %%
def load_data(file_name):
    with open(file_name, 'r') as f:
        data = json.load(f)
    return data

# Load datasets
train = load_data(LOCAL_PROCESSED_DATA_PATH / 'dialog-re-binary-enriched/train.json')
test = load_data(LOCAL_PROCESSED_DATA_PATH / 'dialog-re-binary-enriched/test.json')
dev = load_data(LOCAL_PROCESSED_DATA_PATH / 'dialog-re-binary-enriched/dev.json')

# Combine the data
data = train + test + dev

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(data[1])  # Assuming the structure is dialogue followed by list of features

# Replace string labels with integers
le = LabelEncoder()
df['r'] = le.fit_transform(df['r'])

# Separate the features and target variable
X = df.drop(['r'], axis=1)
y = df['r']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 19
#      17 # Replace string labels with integers
#      18 le = LabelEncoder()
# ---> 19 df['r'] = le.fit_transform(df['r'])
#      21 # Separate the features and target variable
#      22 X = df.drop(['r'], axis=1)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'r'
