# %%
import os
os.listdir(LOCAL_PROCESSED_DATA_PATH)
# Out:
# ['.gitkeep',
#  'dialog-re-binary',
#  'dialog-re-ternary',
#  'dialog-re-ternary-oversampled',
#  'dialog-re-ternary-undersampled',
#  'dialog-re-with-no-relation']

# %%
from src.paths import LOCAL_PROCESSED_DATA_PATH
from src.processing.etl import DialogREDatasetTransformer
from src.processing.ner import EntityProcessor
from src.processing.utils import get_counts_and_percentages
import spacy
from spacy import displacy


dt = DialogREDatasetTransformer(LOCAL_PROCESSED_DATA_PATH / 'dialog-re-ternary')
df1 = dt.load_data_to_dataframe()


ep = EntityProcessor(df1)
ep.process_all_documents()
df2 = ep.enrich_data()

d = ep.docs[0]
type(d), d
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1788/1788 [00:44<00:00, 40.46it/s]
# (spacy.tokens.doc.Doc,
#  Speaker 1: Hey!
#  Speaker 2: Hey.
#  Speaker 3: Hey, man. What's up?
#  Speaker 1: Maybe you can tell me. My agent would like to know why I didn't show up at the audition I didn't know I had today. The first good thing she gets me in weeks. How could you not give me the message?!
#  Speaker 3: Well, I'll tell ya I do enjoy guilt, but, ah, it wasn't me.
#  Speaker 2: Yes, it was! It was him! Uh huh! Okay, it was me!
#  Speaker 1: How is it you?
#  Speaker 2: Well, it was just, it was all so crazy, you know. I mean, Chandler was in the closet, counting to 10, and he was up to 7 and I hadn't found a place to hide yet. I-I-I meant to tell you, and I wrote it all down on my hand. See, all of it.
#  Speaker 1: Yep, that's my audition.
#  Speaker 4: See, now this is why I keep notepads everywhere.
#  Speaker 2: Yep, and that's why we don't invite you to play.
#  Speaker 5: What is the great tragedy here? You go get yourself another appointment.
#  Speaker 1: Well, Estelle tried, you know. The casting director told her that I missed my chance.
#  Speaker 2: That is unfair. I'll call her and tell her it was totally my fault.
#  Speaker 1: Pheebs, you can't do that. The casting director doesn't talk to friends, she only talks to agents.
#  Speaker 2: What a sad little life she must lead. Okay, ooh.
#  Speaker 1: What, what are you doing? What are you doing?
#  Speaker 2: No, no, no, I know, I know, ooh. 'Hi, this is Katelynn, from Phoebe Buffay's office. Um, is um, Ann there for Phoebe, she'll know what it's about.'
#  Speaker 1: Hang up, hang up.
#  Speaker 2: 'Annie! Hi. Listen we got a problem with Joey Tribbiani, apparently he missed his audition. Who did you speak to in my office? Estelle, no, I don't know what I'm going to do with her. No. All right, so your husband leaves and burns down the apartment, the world does not stop.'
#  Speaker 3: Is anybody else scared?
#  Speaker 2: 'Right, well look, um, if Joey loses this audition, that is it for Estelle. I don't care! Annie you are a doll, what time can you see him?' I need a pen.
#  Speaker 3: Get the woman a pad! Get the woman a pad! A pad! A pad!
#  Speaker 4: Oh, now you want a pad.)

# %% [markdown]
# ## Goals of Notebook
# 1. Create entity distance metric
# 2. Create hobby keyword spotter

# %%
import re
from itertools import combinations, permutations

class EntityCombiner:
    def __init__(self, doc, ignore_entity_types=None, entities=None, relations=None):
        if ignore_entity_types is None:
            ignore_entity_types = []
        self.doc = doc
        if entities is None:
            self.entities = [ent for ent in doc.ents if ent.label_ not in ignore_entity_types]
        else:
            self.entities = [ent for ent in doc.ents if ent.text in entities and ent.label_ not in ignore_entity_types]
        self.relations = relations

    def _calculate_turn_distance(self, pairs_generator):
        entity_turns = dict()
        current_turn = 0
        for sentence in self.doc.sents:
            if re.match(r'Speaker \d+:', sentence.text):
                current_turn += 1
            for entity in self.entities:
                if entity.start >= sentence.start and entity.end <= sentence.end:
                    entity_turns[entity] = current_turn
        entity_pairs = pairs_generator(self.entities, 2)
        entity_pairs_distance = [(pair[0], pair[1], abs(entity_turns.get(pair[0], 0) - entity_turns.get(pair[1], 0))) for pair in entity_pairs]
        return entity_pairs_distance

    def _calculate_word_distance(self, pairs_generator):
        entity_pairs = pairs_generator(self.entities, 2)
        entity_pairs_distance = [(pair[0], pair[1], abs(pair[0].start - pair[1].end)) for pair in entity_pairs]
        return entity_pairs_distance

    def get_entity_pairs(self, distance_type='turn', combination_type='combinations'):
        if distance_type == 'turn':
            if combination_type == 'combinations':
                return self._calculate_turn_distance(combinations)
            elif combination_type == 'permutations':
                return self._calculate_turn_distance(permutations)
            else:
                raise ValueError("Invalid combination_type. Supported values are 'combinations' and 'permutations'.")
        elif distance_type == 'word':
            if combination_type == 'combinations':
                return self._calculate_word_distance(combinations)
            elif combination_type == 'permutations':
                return self._calculate_word_distance(permutations)
            else:
                raise ValueError("Invalid combination_type. Supported values are 'combinations' and 'permutations'.")
        else:
            raise ValueError("Invalid distance_type. Supported values are 'turn' and 'word'.")

    def get_relation_tuples(self):
        relation_tuples = []
        for r in self.relations:
            x_entity = next((e for e in self.entities if e.text == r['x']), None)
            y_entity = next((e for e in self.entities if e.text == r['y']), None)
            if x_entity and y_entity:
                turn_distance = abs(x_entity.start - y_entity.start)
                # the start of the first entity and the end of the second entity
                word_distance_start = abs(x_entity.start - y_entity.end)
                # the end of the first entity and the start of the second entity
                word_distance_end = abs(x_entity.end - y_entity.start)
                relation_tuples.append((x_entity.text, y_entity.text, turn_distance, word_distance_start, word_distance_end, r['r'][0]))
        return relation_tuples

# %%
df2.apply(lambda row: [e.split(':')[0] for e in row['UniqueEntities']], axis=1)
# Out:
# 0       [Estelle, Ann, casting director, Katelynn, Ann...
# 1                                                  [Jack]
# 2       [Emma, Mrs. Geller, man, dad, Geller, one, Mr....
# 3                                          [roomie, baby]
# 4                                              [Ross, 26]
#                               ...
# 1783                     [Susie Moss, man, Chandler Bing]
# 1784                                     [Bing, sir, Sir]
# 1785                            [Rach, baby, little girl]
# 1786                                           [Butt Guy]
# 1787                                   [Pheebs, Racquela]
# Length: 1788, dtype: object

# %%
df2.Relations.iloc[0]
# Out:
# [{'y': 'casting director',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Annie',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['agent'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Annie',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'casting director',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'agent',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'}]

# %%
def get_relation_tuples(row):
    unique_entities = [e.split(':')[0] for e in row['UniqueEntities']]
    ec = EntityCombiner(d, ignore_entity_types=['CARDINAL'], entities=unique_entities, relations=row['Relations'])
    return ec.get_relation_tuples()

df2['RelationTuples'] = df2.apply(get_relation_tuples, axis=1)

# %%
df2['RelationTuples']
# Out:
# 0       [(Ann, Annie, 29, 30, 28, with_relation), (Ann...
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
#                               ...
# 1783                                                   []
# 1784                                                   []
# 1785                                                   []
# 1786                                                   []
# 1787                                                   []
# Name: RelationTuples, Length: 1788, dtype: object

# %%
df2.Relations.iloc[0]
# Out:
# [{'y': 'casting director',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Annie',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['agent'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Annie',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'casting director',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'agent',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'}]

# %%
df2['RelationTuples'].iloc[0]
# Out:
# [('Ann', 'Annie', 29, 30, 'with_relation'),
#  ('Annie', 'Annie', 0, 1, 'no_relation'),
#  ('Estelle', 'Katelynn', 121, 122, 'no_relation'),
#  ('Ann', 'Joey Tribbiani', 39, 41, 'no_relation'),
#  ('Estelle', 'Annie', 163, 164, 'no_relation'),
#  ('Annie', 'Joey Tribbiani', 10, 12, 'no_relation'),
#  ('Ann', 'Katelynn', 13, 12, 'no_relation'),
#  ('Estelle', 'Joey Tribbiani', 173, 175, 'no_relation'),
#  ('Annie', 'Katelynn', 42, 41, 'no_relation')]

# %%
mask = df2['RelationTuples'].apply(lambda x: x!=[])
df2[mask]['RelationTuples']
# Out:
# 0       [(Ann, Annie, 29, 30, with_relation), (Annie, ...
# 29              [(Chandler, Chandler, 0, 1, no_relation)]
# 36                [(Estelle, Estelle, 0, 1, no_relation)]
# 64              [(Chandler, Chandler, 0, 1, no_relation)]
# 77                      [(Joey, Joey, 0, 1, no_relation)]
#                               ...
# 1651    [(Joey, Chandler, 373, 372, no_relation), (Joe...
# 1683            [(Chandler, Chandler, 0, 1, no_relation)]
# 1688    [(Joey Tribbiani, Joey Tribbiani, 0, 2, no_rel...
# 1723                [(Phoebe, Phoebe, 0, 1, no_relation)]
# 1755                    [(Joey, Joey, 0, 1, no_relation)]
# Name: RelationTuples, Length: 104, dtype: object

# %%
unique_entities = df2.UniqueEntities.apply(lambda x: [e.split(':')[0] for e in x]).iloc[0]
unique_entities

ec = EntityCombiner(d, ignore_entity_types=['CARDINAL'], entities=unique_entities)
ec.get_entity_pairs(distance_type='turn', combination_type='permutations')
# Out:
# [(Estelle, Katelynn, 4),
#  (Estelle, Ann, 4),
#  (Estelle, Annie, 5),
#  (Estelle, Joey Tribbiani, 5),
#  (Estelle, Estelle, 5),
#  (Estelle, Estelle, 6),
#  (Estelle, Annie, 6),
#  (Katelynn, Estelle, 4),
#  (Katelynn, Ann, 0),
#  (Katelynn, Annie, 1),
#  (Katelynn, Joey Tribbiani, 1),
#  (Katelynn, Estelle, 1),
#  (Katelynn, Estelle, 2),
#  (Katelynn, Annie, 2),
#  (Ann, Estelle, 4),
#  (Ann, Katelynn, 0),
#  (Ann, Annie, 1),
#  (Ann, Joey Tribbiani, 1),
#  (Ann, Estelle, 1),
#  (Ann, Estelle, 2),
#  (Ann, Annie, 2),
#  (Annie, Estelle, 5),
#  (Annie, Katelynn, 1),
#  (Annie, Ann, 1),
#  (Annie, Joey Tribbiani, 0),
#  (Annie, Estelle, 0),
#  (Annie, Estelle, 1),
#  (Annie, Annie, 1),
#  (Joey Tribbiani, Estelle, 5),
#  (Joey Tribbiani, Katelynn, 1),
#  (Joey Tribbiani, Ann, 1),
#  (Joey Tribbiani, Annie, 0),
#  (Joey Tribbiani, Estelle, 0),
#  (Joey Tribbiani, Estelle, 1),
#  (Joey Tribbiani, Annie, 1),
#  (Estelle, Estelle, 5),
#  (Estelle, Katelynn, 1),
#  (Estelle, Ann, 1),
#  (Estelle, Annie, 0),
#  (Estelle, Joey Tribbiani, 0),
#  (Estelle, Estelle, 1),
#  (Estelle, Annie, 1),
#  (Estelle, Estelle, 6),
#  (Estelle, Katelynn, 2),
#  (Estelle, Ann, 2),
#  (Estelle, Annie, 1),
#  (Estelle, Joey Tribbiani, 1),
#  (Estelle, Estelle, 1),
#  (Estelle, Annie, 0),
#  (Annie, Estelle, 6),
#  (Annie, Katelynn, 2),
#  (Annie, Ann, 2),
#  (Annie, Annie, 1),
#  (Annie, Joey Tribbiani, 1),
#  (Annie, Estelle, 1),
#  (Annie, Estelle, 0)]

# %%
df2.Relations.iloc[0]
# Out:
# [{'y': 'casting director',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Annie',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['agent'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Annie',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'casting director',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'agent',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'}]

# %%
entity_combiner = EntityCombiner(d, ignore_entity_types=['CARDINAL'])
entity_pairs = entity_combiner.get_entity_pairs(distance_type='turn', combination_type='combinations')
print("Combinations:")
print(entity_pairs)

entity_pairs = entity_combiner.get_entity_pairs(distance_type='turn', combination_type='permutations')
print("Permutations:")
print(entity_pairs)
# Out:
# Combinations:
# [(today, first, 0), (today, weeks, 0), (today, Chandler, 4), (today, Estelle, 9), (today, Katelynn, 13), (today, Phoebe Buffay's, 13), (today, Ann, 13), (today, Phoebe, 13), (today, Annie, 14), (today, Joey Tribbiani, 14), (today, Estelle, 14), (today, Joey, 15), (today, Estelle, 15), (today, Annie, 15), (first, weeks, 0), (first, Chandler, 4), (first, Estelle, 9), (first, Katelynn, 13), (first, Phoebe Buffay's, 13), (first, Ann, 13), (first, Phoebe, 13), (first, Annie, 14), (first, Joey Tribbiani, 14), (first, Estelle, 14), (first, Joey, 15), (first, Estelle, 15), (first, Annie, 15), (weeks, Chandler, 4), (weeks, Estelle, 9), (weeks, Katelynn, 13), (weeks, Phoebe Buffay's, 13), (weeks, Ann, 13), (weeks, Phoebe, 13), (weeks, Annie, 14), (weeks, Joey Tribbiani, 14), (weeks, Estelle, 14), (weeks, Joey, 15), (weeks, Estelle, 15), (weeks, Annie, 15), (Chandler, Estelle, 5), (Chandler, Katelynn, 9), (Chandler, Phoebe Buffay's, 9), (Chandler, Ann, 9), (Chandler, Phoebe, 9), (Chandler, Annie, 10), (Chandler, Joey Tribbiani, 10), (Chandler, Estelle, 10), (Chandler, Joey, 11), (Chandler, Estelle, 11), (Chandler, Annie, 11), (Estelle, Katelynn, 4), (Estelle, Phoebe Buffay's, 4), (Estelle, Ann, 4), (Estelle, Phoebe, 4), (Estelle, Annie, 5), (Estelle, Joey Tribbiani, 5), (Estelle, Estelle, 5), (Estelle, Joey, 6), (Estelle, Estelle, 6), (Estelle, Annie, 6), (Katelynn, Phoebe Buffay's, 0), (Katelynn, Ann, 0), (Katelynn, Phoebe, 0), (Katelynn, Annie, 1), (Katelynn, Joey Tribbiani, 1), (Katelynn, Estelle, 1), (Katelynn, Joey, 2), (Katelynn, Estelle, 2), (Katelynn, Annie, 2), (Phoebe Buffay's, Ann, 0), (Phoebe Buffay's, Phoebe, 0), (Phoebe Buffay's, Annie, 1), (Phoebe Buffay's, Joey Tribbiani, 1), (Phoebe Buffay's, Estelle, 1), (Phoebe Buffay's, Joey, 2), (Phoebe Buffay's, Estelle, 2), (Phoebe Buffay's, Annie, 2), (Ann, Phoebe, 0), (Ann, Annie, 1), (Ann, Joey Tribbiani, 1), (Ann, Estelle, 1), (Ann, Joey, 2), (Ann, Estelle, 2), (Ann, Annie, 2), (Phoebe, Annie, 1), (Phoebe, Joey Tribbiani, 1), (Phoebe, Estelle, 1), (Phoebe, Joey, 2), (Phoebe, Estelle, 2), (Phoebe, Annie, 2), (Annie, Joey Tribbiani, 0), (Annie, Estelle, 0), (Annie, Joey, 1), (Annie, Estelle, 1), (Annie, Annie, 1), (Joey Tribbiani, Estelle, 0), (Joey Tribbiani, Joey, 1), (Joey Tribbiani, Estelle, 1), (Joey Tribbiani, Annie, 1), (Estelle, Joey, 1), (Estelle, Estelle, 1), (Estelle, Annie, 1), (Joey, Estelle, 0), (Joey, Annie, 0), (Estelle, Annie, 0)]
# Permutations:
# [(today, first, 0), (today, weeks, 0), (today, Chandler, 4), (today, Estelle, 9), (today, Katelynn, 13), (today, Phoebe Buffay's, 13), (today, Ann, 13), (today, Phoebe, 13), (today, Annie, 14), (today, Joey Tribbiani, 14), (today, Estelle, 14), (today, Joey, 15), (today, Estelle, 15), (today, Annie, 15), (first, today, 0), (first, weeks, 0), (first, Chandler, 4), (first, Estelle, 9), (first, Katelynn, 13), (first, Phoebe Buffay's, 13), (first, Ann, 13), (first, Phoebe, 13), (first, Annie, 14), (first, Joey Tribbiani, 14), (first, Estelle, 14), (first, Joey, 15), (first, Estelle, 15), (first, Annie, 15), (weeks, today, 0), (weeks, first, 0), (weeks, Chandler, 4), (weeks, Estelle, 9), (weeks, Katelynn, 13), (weeks, Phoebe Buffay's, 13), (weeks, Ann, 13), (weeks, Phoebe, 13), (weeks, Annie, 14), (weeks, Joey Tribbiani, 14), (weeks, Estelle, 14), (weeks, Joey, 15), (weeks, Estelle, 15), (weeks, Annie, 15), (Chandler, today, 4), (Chandler, first, 4), (Chandler, weeks, 4), (Chandler, Estelle, 5), (Chandler, Katelynn, 9), (Chandler, Phoebe Buffay's, 9), (Chandler, Ann, 9), (Chandler, Phoebe, 9), (Chandler, Annie, 10), (Chandler, Joey Tribbiani, 10), (Chandler, Estelle, 10), (Chandler, Joey, 11), (Chandler, Estelle, 11), (Chandler, Annie, 11), (Estelle, today, 9), (Estelle, first, 9), (Estelle, weeks, 9), (Estelle, Chandler, 5), (Estelle, Katelynn, 4), (Estelle, Phoebe Buffay's, 4), (Estelle, Ann, 4), (Estelle, Phoebe, 4), (Estelle, Annie, 5), (Estelle, Joey Tribbiani, 5), (Estelle, Estelle, 5), (Estelle, Joey, 6), (Estelle, Estelle, 6), (Estelle, Annie, 6), (Katelynn, today, 13), (Katelynn, first, 13), (Katelynn, weeks, 13), (Katelynn, Chandler, 9), (Katelynn, Estelle, 4), (Katelynn, Phoebe Buffay's, 0), (Katelynn, Ann, 0), (Katelynn, Phoebe, 0), (Katelynn, Annie, 1), (Katelynn, Joey Tribbiani, 1), (Katelynn, Estelle, 1), (Katelynn, Joey, 2), (Katelynn, Estelle, 2), (Katelynn, Annie, 2), (Phoebe Buffay's, today, 13), (Phoebe Buffay's, first, 13), (Phoebe Buffay's, weeks, 13), (Phoebe Buffay's, Chandler, 9), (Phoebe Buffay's, Estelle, 4), (Phoebe Buffay's, Katelynn, 0), (Phoebe Buffay's, Ann, 0), (Phoebe Buffay's, Phoebe, 0), (Phoebe Buffay's, Annie, 1), (Phoebe Buffay's, Joey Tribbiani, 1), (Phoebe Buffay's, Estelle, 1), (Phoebe Buffay's, Joey, 2), (Phoebe Buffay's, Estelle, 2), (Phoebe Buffay's, Annie, 2), (Ann, today, 13), (Ann, first, 13), (Ann, weeks, 13), (Ann, Chandler, 9), (Ann, Estelle, 4), (Ann, Katelynn, 0), (Ann, Phoebe Buffay's, 0), (Ann, Phoebe, 0), (Ann, Annie, 1), (Ann, Joey Tribbiani, 1), (Ann, Estelle, 1), (Ann, Joey, 2), (Ann, Estelle, 2), (Ann, Annie, 2), (Phoebe, today, 13), (Phoebe, first, 13), (Phoebe, weeks, 13), (Phoebe, Chandler, 9), (Phoebe, Estelle, 4), (Phoebe, Katelynn, 0), (Phoebe, Phoebe Buffay's, 0), (Phoebe, Ann, 0), (Phoebe, Annie, 1), (Phoebe, Joey Tribbiani, 1), (Phoebe, Estelle, 1), (Phoebe, Joey, 2), (Phoebe, Estelle, 2), (Phoebe, Annie, 2), (Annie, today, 14), (Annie, first, 14), (Annie, weeks, 14), (Annie, Chandler, 10), (Annie, Estelle, 5), (Annie, Katelynn, 1), (Annie, Phoebe Buffay's, 1), (Annie, Ann, 1), (Annie, Phoebe, 1), (Annie, Joey Tribbiani, 0), (Annie, Estelle, 0), (Annie, Joey, 1), (Annie, Estelle, 1), (Annie, Annie, 1), (Joey Tribbiani, today, 14), (Joey Tribbiani, first, 14), (Joey Tribbiani, weeks, 14), (Joey Tribbiani, Chandler, 10), (Joey Tribbiani, Estelle, 5), (Joey Tribbiani, Katelynn, 1), (Joey Tribbiani, Phoebe Buffay's, 1), (Joey Tribbiani, Ann, 1), (Joey Tribbiani, Phoebe, 1), (Joey Tribbiani, Annie, 0), (Joey Tribbiani, Estelle, 0), (Joey Tribbiani, Joey, 1), (Joey Tribbiani, Estelle, 1), (Joey Tribbiani, Annie, 1), (Estelle, today, 14), (Estelle, first, 14), (Estelle, weeks, 14), (Estelle, Chandler, 10), (Estelle, Estelle, 5), (Estelle, Katelynn, 1), (Estelle, Phoebe Buffay's, 1), (Estelle, Ann, 1), (Estelle, Phoebe, 1), (Estelle, Annie, 0), (Estelle, Joey Tribbiani, 0), (Estelle, Joey, 1), (Estelle, Estelle, 1), (Estelle, Annie, 1), (Joey, today, 15), (Joey, first, 15 ...

# %%
df2.Relations.iloc[0]
# Out:
# [{'y': 'casting director',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Annie',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['agent'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Annie',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'casting director',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'agent',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'}]

# %%
df2.CorrectPredictions.iloc[0]
# Out:
# ['Katelynn:PERSON',
#  'Estelle:PERSON',
#  'Joey Tribbiani:PERSON',
#  'Annie:PERSON',
#  'Ann:PERSON',
#  'Phoebe Buffay:PERSON']

# %%
df2.apply(lambda row: [(r['x'], r['y'], r['r'][0]) 
                       for r in row['Relations'] 
                       if (r['x'] in [cp.split(':')[0] for cp in row['CorrectPredictions']] 
                           and r['y'] in [cp.split(':')[0] for cp in row['CorrectPredictions']])], 
                       axis=1).explode().value_counts()Q
# Out:
# (Ross, Ross, no_relation)                 61
# (Rachel, Rachel, no_relation)             58
# (Chandler, Chandler, no_relation)         47
# (Monica, Monica, no_relation)             47
# (Joey, Joey, no_relation)                 36
#                                           ..
# (Egypt, Egypt, no_relation)                1
# (Pete, Richard, no_relation)               1
# (Richard, Pete, no_relation)               1
# (Phoebe, Phoebe Buffay, with_relation)     1
# (Nancy, Nancy, no_relation)                1
# Length: 1471, dtype: int64

# %%
df2.Relations.explode().apply( lambda x: x['r'][0])
# Out:
# 0       with_relation
# 0       with_relation
# 0       with_relation
# 0       with_relation
# 0       with_relation
#             ...
# 1787      no_relation
# 1787      no_relation
# 1787      no_relation
# 1787      no_relation
# 1787      no_relation
# Name: Relations, Length: 26238, dtype: object

# %%
get_counts_and_percentages(pd.DataFrame(df2.Relations.explode().apply( lambda x: x['r'][0])), cols=['Relations'])
# Out:
#                Counts     %
# Relations
# no_relation     16489  62.8
# with_relation    7650  29.2
# unanswerable     2099   8.0

# %%
get_counts_and_percentages(pd.DataFrame(df2.apply(lambda row: [(0, r['r'][0]) 
                       for r in row['Relations'] 
                       if (r['x'] in [cp.split(':')[0] for cp in row['CorrectPredictions']] 
                           and r['y'] in [cp.split(':')[0] for cp in row['CorrectPredictions']])], 
                       axis=1).explode().rename('Relations')), cols=['Relations'])


#.value_counts()
# Out:
#                     Counts     %
# Relations
# (0, no_relation)      1995  84.7
# (0, with_relation)     357  15.2
# (0, unanswerable)        3   0.1

# %%
displacy.render(d, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Hey!</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Hey.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Hey, man. What's up?</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Maybe you can tell me. My agent would like to know why I didn't show up at the audition I didn't know I had
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  good thing she gets me in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . How could you not give me the message?!</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Well, I'll tell ya I do enjoy guilt, but, ah, it wasn't me.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Yes, it was! It was him! Uh huh! Okay, it was me!</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : How is it you?</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Well, it was just, it was all so crazy, you know. I mean,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chandler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was in the closet, counting to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , and he was up to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and I hadn't found a place to hide yet. I-I-I meant to tell you, and I wrote it all down on my hand. See, all of it.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Yep, that's my audition.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : See, now this is why I keep notepads everywhere.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Yep, and that's why we don't invite you to play.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : What is the great tragedy here? You go get yourself another appointment.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Well,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Estelle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tried, you know. The casting director told her that I missed my chance.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : That is unfair. I'll call her and tell her it was totally my fault.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Pheebs, you can't do that. The casting director doesn't talk to friends, she only talks to agents.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6

# %%
ignore_entity_types=['CARDINAL']
entities = set([ent for ent in d.ents if ent.label_ not in ignore_entity_types]) 
len(entities), entities
# Out:
# (15,
#  {today,
#   first,
#   weeks,
#   Chandler,
#   Estelle,
#   Katelynn,
#   Phoebe Buffay's,
#   Ann,
#   Phoebe,
#   Annie,
#   Joey Tribbiani,
#   Estelle,
#   Joey,
#   Estelle,
#   Annie})

# %%
len(entities)*(len(entities)-1)/2
# Out:
# 105.0

# %% [markdown]
# ####

# %%
from itertools import permutations, combinations

def entity_pair_combinations(doc, ignore_entity_types=None):
    if ignore_entity_types is None:
        ignore_entity_types = []

    entities = set([ent for ent in doc.ents if ent.label_ not in ignore_entity_types])  # filter out entities in the ignore list
    entity_pairs = list(combinations(entities, 2))  # create permutations of entity pairs
    entity_pairs_distance = [(pair[0], pair[1], abs(pair[0].start - pair[1].end)) for pair in entity_pairs]  # calculate word distance
    return entity_pairs_distance

# %%
pairs = entity_pair_combinations(d, ignore_entity_types=['CARDINAL'])
len(pairs), pairs
# Out:
# (105,
#  [(Estelle, Ann, 135),
#   (Estelle, Chandler, 120),
#   (Estelle, first, 216),
#   (Estelle, Estelle, 192),
#   (Estelle, Joey, 253),
#   (Estelle, Estelle, 262),
#   (Estelle, Phoebe, 138),
#   (Estelle, Joey Tribbiani, 175),
#   (Estelle, Katelynn, 122),
#   (Estelle, today, 219),
#   (Estelle, Annie, 164),
#   (Estelle, Phoebe Buffay's, 127),
#   (Estelle, weeks, 209),
#   (Estelle, Annie, 269),
#   (Ann, Chandler, 254),
#   (Ann, first, 350),
#   (Ann, Estelle, 58),
#   (Ann, Joey, 119),
#   (Ann, Estelle, 128),
#   (Ann, Phoebe, 4),
#   (Ann, Joey Tribbiani, 41),
#   (Ann, Katelynn, 12),
#   (Ann, today, 353),
#   (Ann, Annie, 30),
#   (Ann, Phoebe Buffay's, 7),
#   (Ann, weeks, 343),
#   (Ann, Annie, 135),
#   (Chandler, first, 95),
#   (Chandler, Estelle, 313),
#   (Chandler, Joey, 374),
#   (Chandler, Estelle, 383),
#   (Chandler, Phoebe, 259),
#   (Chandler, Joey Tribbiani, 296),
#   (Chandler, Katelynn, 243),
#   (Chandler, today, 98),
#   (Chandler, Annie, 285),
#   (Chandler, Phoebe Buffay's, 248),
#   (Chandler, weeks, 88),
#   (Chandler, Annie, 390),
#   (first, Estelle, 409),
#   (first, Joey, 470),
#   (first, Estelle, 479),
#   (first, Phoebe, 355),
#   (first, Joey Tribbiani, 392),
#   (first, Katelynn, 339),
#   (first, today, 2),
#   (first, Annie, 381),
#   (first, Phoebe Buffay's, 344),
#   (first, weeks, 8),
#   (first, Annie, 486),
#   (Estelle, Joey, 62),
#   (Estelle, Estelle, 71),
#   (Estelle, Phoebe, 53),
#   (Estelle, Joey Tribbiani, 16),
#   (Estelle, Katelynn, 69),
#   (Estelle, today, 410),
#   (Estelle, Annie, 27),
#   (Estelle, Phoebe Buffay's, 64),
#   (Estelle, weeks, 400),
#   (Estelle, Annie, 78),
#   (Joey, Estelle, 10),
#   (Joey, Phoebe, 114),
#   (Joey, Joey Tribbiani, 77),
#   (Joey, Katelynn, 130),
#   (Joey, today, 471),
#   (Joey, Annie, 88),
#   (Joey, Phoebe Buffay's, 125),
#   (Joey, weeks, 461),
#   (Joey, Annie, 17),
#   (Estelle, Phoebe, 123),
#   (Estelle, Joey Tribbiani, 86),
#   (Estelle, Katelynn, 139),
#   (Estelle, today, 480),
#   (Estelle, Annie, 97),
#   (Estelle, Phoebe Buffay's, 134),
#   (Estelle, weeks, 470),
#   (Estelle, Annie, 8),
#   (Phoebe, Joey Tribbiani, 38),
#   (Phoebe, Katelynn, 15),
#   (Phoebe, today, 356),
#   (Phoebe, Annie, 27),
#   (Phoebe, Phoebe Buffay's, 10),
#   (Phoebe, weeks, 346),
#   (Phoebe, Annie, 132),
#   (Joey Tribbiani, Katelynn, 51),
#   (Joey Tribbiani, today, 392),
#   (Joey Tribbiani, Annie, 9),
#   (Joey Tribbiani, Phoebe Buffay's, 46),
#   (Joey Tribbiani, weeks, 382),
#   (Joey Tribbiani, Annie, 96),
#   (Katelynn, today, 340),
#   (Katelynn, Annie, 43),
#   (Katelynn, Phoebe Buffay's, 6),
#   (Katelynn, weeks, 330),
#   (Katelynn, Annie, 148),
#   (today, Annie, 384),
#   (today, Phoebe Buffay's, 347),
#   (today, weeks, 11),
#   (today, Annie, 489),
#   (Annie, Phoebe Buffay's, 36),
#   (Annie, weeks, 372),
#   (Annie, Annie, 106),
#   (Phoebe Buffay's, weeks, 333),
#   (Phoebe Buffay's, Annie, 145),
#   (weeks, Annie, 479)])

# %%
len(d.text.split('\n'))
# Out:
# 24

# %%
import re
from itertools import combinations

from itertools import combinations

def entity_pair_combinations_turn(doc, ignore_entity_types=None):
    if ignore_entity_types is None:
        ignore_entity_types = []

    entities = [ent for ent in doc.ents if ent.label_ not in ignore_entity_types]  # filter out entities in the ignore list

    # Find the turn number for each entity
    entity_turns = dict()
    current_turn = 0
    for sentence in doc.sents:
        if re.match(r'Speaker \d+:', sentence.text):
            current_turn += 1
        for entity in entities:
            if entity.start >= sentence.start and entity.end <= sentence.end:
                entity_turns[entity] = current_turn

    entity_pairs = combinations(entities, 2)  # create combinations of entity pairs
    entity_pairs_distance = [(pair[0], pair[1], abs(entity_turns.get(pair[0], 0) - entity_turns.get(pair[1], 0))) for pair in entity_pairs]  # calculate turn distance
    return entity_pairs_distance


pairs = entity_pair_combinations_turn(d, ignore_entity_types=['CARDINAL'])
len(pairs),pairs
# Out:
# (105,
#  [(today, first, 0),
#   (today, weeks, 0),
#   (today, Chandler, 4),
#   (today, Estelle, 9),
#   (today, Katelynn, 13),
#   (today, Phoebe Buffay's, 13),
#   (today, Ann, 13),
#   (today, Phoebe, 13),
#   (today, Annie, 14),
#   (today, Joey Tribbiani, 14),
#   (today, Estelle, 14),
#   (today, Joey, 15),
#   (today, Estelle, 15),
#   (today, Annie, 15),
#   (first, weeks, 0),
#   (first, Chandler, 4),
#   (first, Estelle, 9),
#   (first, Katelynn, 13),
#   (first, Phoebe Buffay's, 13),
#   (first, Ann, 13),
#   (first, Phoebe, 13),
#   (first, Annie, 14),
#   (first, Joey Tribbiani, 14),
#   (first, Estelle, 14),
#   (first, Joey, 15),
#   (first, Estelle, 15),
#   (first, Annie, 15),
#   (weeks, Chandler, 4),
#   (weeks, Estelle, 9),
#   (weeks, Katelynn, 13),
#   (weeks, Phoebe Buffay's, 13),
#   (weeks, Ann, 13),
#   (weeks, Phoebe, 13),
#   (weeks, Annie, 14),
#   (weeks, Joey Tribbiani, 14),
#   (weeks, Estelle, 14),
#   (weeks, Joey, 15),
#   (weeks, Estelle, 15),
#   (weeks, Annie, 15),
#   (Chandler, Estelle, 5),
#   (Chandler, Katelynn, 9),
#   (Chandler, Phoebe Buffay's, 9),
#   (Chandler, Ann, 9),
#   (Chandler, Phoebe, 9),
#   (Chandler, Annie, 10),
#   (Chandler, Joey Tribbiani, 10),
#   (Chandler, Estelle, 10),
#   (Chandler, Joey, 11),
#   (Chandler, Estelle, 11),
#   (Chandler, Annie, 11),
#   (Estelle, Katelynn, 4),
#   (Estelle, Phoebe Buffay's, 4),
#   (Estelle, Ann, 4),
#   (Estelle, Phoebe, 4),
#   (Estelle, Annie, 5),
#   (Estelle, Joey Tribbiani, 5),
#   (Estelle, Estelle, 5),
#   (Estelle, Joey, 6),
#   (Estelle, Estelle, 6),
#   (Estelle, Annie, 6),
#   (Katelynn, Phoebe Buffay's, 0),
#   (Katelynn, Ann, 0),
#   (Katelynn, Phoebe, 0),
#   (Katelynn, Annie, 1),
#   (Katelynn, Joey Tribbiani, 1),
#   (Katelynn, Estelle, 1),
#   (Katelynn, Joey, 2),
#   (Katelynn, Estelle, 2),
#   (Katelynn, Annie, 2),
#   (Phoebe Buffay's, Ann, 0),
#   (Phoebe Buffay's, Phoebe, 0),
#   (Phoebe Buffay's, Annie, 1),
#   (Phoebe Buffay's, Joey Tribbiani, 1),
#   (Phoebe Buffay's, Estelle, 1),
#   (Phoebe Buffay's, Joey, 2),
#   (Phoebe Buffay's, Estelle, 2),
#   (Phoebe Buffay's, Annie, 2),
#   (Ann, Phoebe, 0),
#   (Ann, Annie, 1),
#   (Ann, Joey Tribbiani, 1),
#   (Ann, Estelle, 1),
#   (Ann, Joey, 2),
#   (Ann, Estelle, 2),
#   (Ann, Annie, 2),
#   (Phoebe, Annie, 1),
#   (Phoebe, Joey Tribbiani, 1),
#   (Phoebe, Estelle, 1),
#   (Phoebe, Joey, 2),
#   (Phoebe, Estelle, 2),
#   (Phoebe, Annie, 2),
#   (Annie, Joey Tribbiani, 0),
#   (Annie, Estelle, 0),
#   (Annie, Joey, 1),
#   (Annie, Estelle, 1),
#   (Annie, Annie, 1),
#   (Joey Tribbiani, Estelle, 0),
#   (Joey Tribbiani, Joey, 1),
#   (Joey Tribbiani, Estelle, 1),
#   (Joey Tribbiani, Annie, 1),
#   (Estelle, Joey, 1),
#   (Estelle, Estelle, 1),
#   (Estelle, Annie, 1),
#   (Joey, Estelle, 0),
#   (Joey, Annie, 0),
#   (Estelle, Annie, 0)])

# %%
ec = EntityCombiner(d, ignore_entity_types=['CARDINAL'])

# %%
ec.get_entity_pairs()
ec.get_entity_pairs('word')
# Out:
# [(today, first, 4),
#  (today, weeks, 11),
#  (today, Chandler, 100),
#  (today, Estelle, 221),
#  (today, Katelynn, 342),
#  (today, Phoebe Buffay's, 347),
#  (today, Ann, 355),
#  (today, Phoebe, 358),
#  (today, Annie, 384),
#  (today, Joey Tribbiani, 395),
#  (today, Estelle, 412),
#  (today, Joey, 473),
#  (today, Estelle, 482),
#  (today, Annie, 489),
#  (first, weeks, 8),
#  (first, Chandler, 97),
#  (first, Estelle, 218),
#  (first, Katelynn, 339),
#  (first, Phoebe Buffay's, 344),
#  (first, Ann, 352),
#  (first, Phoebe, 355),
#  (first, Annie, 381),
#  (first, Joey Tribbiani, 392),
#  (first, Estelle, 409),
#  (first, Joey, 470),
#  (first, Estelle, 479),
#  (first, Annie, 486),
#  (weeks, Chandler, 90),
#  (weeks, Estelle, 211),
#  (weeks, Katelynn, 332),
#  (weeks, Phoebe Buffay's, 337),
#  (weeks, Ann, 345),
#  (weeks, Phoebe, 348),
#  (weeks, Annie, 374),
#  (weeks, Joey Tribbiani, 385),
#  (weeks, Estelle, 402),
#  (weeks, Joey, 463),
#  (weeks, Estelle, 472),
#  (weeks, Annie, 479),
#  (Chandler, Estelle, 122),
#  (Chandler, Katelynn, 243),
#  (Chandler, Phoebe Buffay's, 248),
#  (Chandler, Ann, 256),
#  (Chandler, Phoebe, 259),
#  (Chandler, Annie, 285),
#  (Chandler, Joey Tribbiani, 296),
#  (Chandler, Estelle, 313),
#  (Chandler, Joey, 374),
#  (Chandler, Estelle, 383),
#  (Chandler, Annie, 390),
#  (Estelle, Katelynn, 122),
#  (Estelle, Phoebe Buffay's, 127),
#  (Estelle, Ann, 135),
#  (Estelle, Phoebe, 138),
#  (Estelle, Annie, 164),
#  (Estelle, Joey Tribbiani, 175),
#  (Estelle, Estelle, 192),
#  (Estelle, Joey, 253),
#  (Estelle, Estelle, 262),
#  (Estelle, Annie, 269),
#  (Katelynn, Phoebe Buffay's, 6),
#  (Katelynn, Ann, 14),
#  (Katelynn, Phoebe, 17),
#  (Katelynn, Annie, 43),
#  (Katelynn, Joey Tribbiani, 54),
#  (Katelynn, Estelle, 71),
#  (Katelynn, Joey, 132),
#  (Katelynn, Estelle, 141),
#  (Katelynn, Annie, 148),
#  (Phoebe Buffay's, Ann, 11),
#  (Phoebe Buffay's, Phoebe, 14),
#  (Phoebe Buffay's, Annie, 40),
#  (Phoebe Buffay's, Joey Tribbiani, 51),
#  (Phoebe Buffay's, Estelle, 68),
#  (Phoebe Buffay's, Joey, 129),
#  (Phoebe Buffay's, Estelle, 138),
#  (Phoebe Buffay's, Annie, 145),
#  (Ann, Phoebe, 4),
#  (Ann, Annie, 30),
#  (Ann, Joey Tribbiani, 41),
#  (Ann, Estelle, 58),
#  (Ann, Joey, 119),
#  (Ann, Estelle, 128),
#  (Ann, Annie, 135),
#  (Phoebe, Annie, 27),
#  (Phoebe, Joey Tribbiani, 38),
#  (Phoebe, Estelle, 55),
#  (Phoebe, Joey, 116),
#  (Phoebe, Estelle, 125),
#  (Phoebe, Annie, 132),
#  (Annie, Joey Tribbiani, 12),
#  (Annie, Estelle, 29),
#  (Annie, Joey, 90),
#  (Annie, Estelle, 99),
#  (Annie, Annie, 106),
#  (Joey Tribbiani, Estelle, 19),
#  (Joey Tribbiani, Joey, 80),
#  (Joey Tribbiani, Estelle, 89),
#  (Joey Tribbiani, Annie, 96),
#  (Estelle, Joey, 62),
#  (Estelle, Estelle, 71),
#  (Estelle, Annie, 78),
#  (Joey, Estelle, 10),
#  (Joey, Annie, 17),
#  (Estelle, Annie, 8)]

# %%
def extract_hobbies(doc):
    # List of common hobbies
    hobby_list = [
        'reading', 'writing', 'sports', 'music', 'cooking', 'painting', 'dancing', 'hiking', 'fishing', 
        'gardening', 'photography', 'knitting', 'sewing', 'drawing', 'crafts', 'cycling', 'baking', 'swimming', 
        'camping', 'pottery', 'yoga', 'martial arts', 'singing', 'rock climbing', 'horse riding', 'bird watching', 
        'stamp collecting', 'jewelry making', 'playing guitar', 'playing piano', 'playing violin', 
        'video games', 'board games', 'card games', 'running', 'weightlifting', 'woodworking', 'scrapbooking', 
        'calligraphy', 'quilting', 'embroidery', 'crocheting', 'crossword puzzles', 'jigsaw puzzles', 
        'roller skating', 'skateboarding', 'soccer', 'football', 'basketball', 'tennis', 'golf', 'volleyball', 
        'rugby', 'skiing', 'snowboarding', 'ice skating', 'origami', 'magic', 'acting', 'theatre', 'comedy',
        'traveling', 'cinema', 'astronomy', 'chess', 'billiards', 'snooker', 'poker', 'brewing beer', 'winemaking',
        'blogging', 'podcasting', 'streaming', 'collecting', 'fashion', 'makeup', 'cosplay', 'meditation', 
        'learning languages', 'genealogy', 'archery', 'fencing', 'sailing', 'canoeing', 'kayaking', 'windsurfing', 
        'surfing', 'scuba diving', 'drone racing', 'kart racing', 'drone photography'
    ]

    # Create a regex pattern that looks for these hobbies in the text
    pattern = r'\b(' + '|'.join(hobby_list) + r')\b'

    # Use the pattern to find matches in the text
    matches = re.findall(pattern, doc.text, re.IGNORECASE)
    
    return matches

hobbies = extract_hobbies(d)
print(hobbies)
# Out:
# []

# %%
from tqdm import tqdm

# %%
import pandas as pd

# %%
hobbies = [extract_hobbies(d) for d in ep.docs]
hobbies = [h for h in hobbies if h != []]
tmp = pd.Series(hobbies)
hobby_df = pd.concat([
    tmp.explode().value_counts(),
    tmp.apply(set).explode().value_counts()
], axis=1
         ).rename({
    0: 'ent_count',
    1: 'doc_count'
         },
axis=1)
hobby_df
# Out:
#                 ent_count  doc_count
# writing                23         19
# acting                 20         17
# music                  17         14
# fashion                16         12
# running                15         13
# reading                15         14
# football               14          6
# dancing                13         10
# magic                  10          9
# Pottery                10          2
# makeup                  8          7
# theatre                 7          7
# singing                 7          7
# cooking                 6          6
# basketball              6          5
# sports                  5          5
# skiing                  5          3
# soccer                  4          4
# golf                    4          4
# drawing                 3          3
# rugby                   3          1
# poker                   3          2
# sailing                 3          2
# Sports                  2          2
# fishing                 2          2
# swimming                2          1
# tennis                  2          2
# yoga                    1          1
# Singing                 1          1
# cinema                  1          1
# Magic                   1          1
# baking                  1          1
# traveling               1          1
# Football                1          1
# Music                   1          1
# knitting                1          1
# collecting              1          1
# comedy                  1          1
# photography             1          1
# Cooking                 1          1
# playing guitar          1          1
# painting                1          1
# Theatre                 1          1
# Writing                 1          1
# Rugby                   1          1

# %%
hobby_df['ratio'] = hobby_df['ent_count'] / hobby_df['doc_count']
hobby_df
# Out:
#                 ent_count  doc_count     ratio
# writing                23         19  1.210526
# acting                 20         17  1.176471
# music                  17         14  1.214286
# fashion                16         12  1.333333
# running                15         13  1.153846
# reading                15         14  1.071429
# football               14          6  2.333333
# dancing                13         10  1.300000
# magic                  10          9  1.111111
# Pottery                10          2  5.000000
# makeup                  8          7  1.142857
# theatre                 7          7  1.000000
# singing                 7          7  1.000000
# cooking                 6          6  1.000000
# basketball              6          5  1.200000
# sports                  5          5  1.000000
# skiing                  5          3  1.666667
# soccer                  4          4  1.000000
# golf                    4          4  1.000000
# drawing                 3          3  1.000000
# rugby                   3          1  3.000000
# poker                   3          2  1.500000
# sailing                 3          2  1.500000
# Sports                  2          2  1.000000
# fishing                 2          2  1.000000
# swimming                2          1  2.000000
# tennis                  2          2  1.000000
# yoga                    1          1  1.000000
# Singing                 1          1  1.000000
# cinema                  1          1  1.000000
# Magic                   1          1  1.000000
# baking                  1          1  1.000000
# traveling               1          1  1.000000
# Football                1          1  1.000000
# Music                   1          1  1.000000
# knitting                1          1  1.000000
# collecting              1          1  1.000000
# comedy                  1          1  1.000000
# photography             1          1  1.000000
# Cooking                 1          1  1.000000
# playing guitar          1          1  1.000000
# painting                1          1  1.000000
# Theatre                 1          1  1.000000
# Writing                 1          1  1.000000
# Rugby                   1          1  1.000000

# %%
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting', 'acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['dancing', 'dancing'],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  ['cinema'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  ['fashion', 'fashion'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['basketball', 'basketball'],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  [],
#  [],
#  [],
#  ['yoga'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['skiing', 'skiing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing'],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Pottery', 'Pottery', 'Pottery', 'Pottery'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['sailing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Singing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Pottery', 'Pottery', 'Pottery', 'Pottery', 'Pottery', 'Pottery'],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fishing'],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['basketball', 'Sports'],
#  ['makeup'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['golf'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['golf'],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['makeup'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['dancing', 'dancing'],
#  [],
#  ['dancing', 'dancing'],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['basketball'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['poker'],
#  [],
#  ['writing', 'writing'],
#  [],
#  ['drawing'],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['makeup'],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  ['singing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing', 'writing', 'writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['drawing'],
#  ['fashion'],
#  [],
#  [],
#  [],
#  [],
#  ['magic', 'magic'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing'],
#  [],
#  [],
#  ['football', 'football', 'football', 'running', 'football'],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fashion'],
#  ['football', 'football'],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fashion'],
#  ['sports'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['football'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['football'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running', 'running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing', 'music', 'music', 'music', 'music', 'cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  ['poker', 'poker'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['makeup', 'soccer'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Sports', 'sports'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['soccer'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading', 'reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  ['cooking'],
#  [],
#  [],
#  [],
#  [],
#  ['fashion'],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]
