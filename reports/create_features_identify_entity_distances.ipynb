# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.paths import LOCAL_PROCESSED_DATA_PATH
from src.processing.etl import DialogREDatasetTransformer
from src.processing.ner import EntityProcessor
from src.processing.utils import get_counts_and_percentages
from tqdm import tqdm
import pandas as pd
import spacy
from spacy import displacy


dt = DialogREDatasetTransformer(LOCAL_PROCESSED_DATA_PATH / 'dialog-re-ternary')
df1 = dt.load_data_to_dataframe()


ep = EntityProcessor(df1)
ep.process_all_documents()
df2 = ep.enrich_data(ignore_substring_entities=[])

d = ep.docs[0]
type(d), d
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1788/1788 [00:50<00:00, 35.61it/s]
# (spacy.tokens.doc.Doc,
#  Speaker 1: Hey!
#  Speaker 2: Hey.
#  Speaker 3: Hey, man. What's up?
#  Speaker 1: Maybe you can tell me. My agent would like to know why I didn't show up at the audition I didn't know I had today. The first good thing she gets me in weeks. How could you not give me the message?!
#  Speaker 3: Well, I'll tell ya I do enjoy guilt, but, ah, it wasn't me.
#  Speaker 2: Yes, it was! It was him! Uh huh! Okay, it was me!
#  Speaker 1: How is it you?
#  Speaker 2: Well, it was just, it was all so crazy, you know. I mean, Chandler was in the closet, counting to 10, and he was up to 7 and I hadn't found a place to hide yet. I-I-I meant to tell you, and I wrote it all down on my hand. See, all of it.
#  Speaker 1: Yep, that's my audition.
#  Speaker 4: See, now this is why I keep notepads everywhere.
#  Speaker 2: Yep, and that's why we don't invite you to play.
#  Speaker 5: What is the great tragedy here? You go get yourself another appointment.
#  Speaker 1: Well, Estelle tried, you know. The casting director told her that I missed my chance.
#  Speaker 2: That is unfair. I'll call her and tell her it was totally my fault.
#  Speaker 1: Pheebs, you can't do that. The casting director doesn't talk to friends, she only talks to agents.
#  Speaker 2: What a sad little life she must lead. Okay, ooh.
#  Speaker 1: What, what are you doing? What are you doing?
#  Speaker 2: No, no, no, I know, I know, ooh. 'Hi, this is Katelynn, from Phoebe Buffay's office. Um, is um, Ann there for Phoebe, she'll know what it's about.'
#  Speaker 1: Hang up, hang up.
#  Speaker 2: 'Annie! Hi. Listen we got a problem with Joey Tribbiani, apparently he missed his audition. Who did you speak to in my office? Estelle, no, I don't know what I'm going to do with her. No. All right, so your husband leaves and burns down the apartment, the world does not stop.'
#  Speaker 3: Is anybody else scared?
#  Speaker 2: 'Right, well look, um, if Joey loses this audition, that is it for Estelle. I don't care! Annie you are a doll, what time can you see him?' I need a pen.
#  Speaker 3: Get the woman a pad! Get the woman a pad! A pad! A pad!
#  Speaker 4: Oh, now you want a pad.)

# %%
df2['SpacyDialogue'] = ep.docs

# %%
df2
# Out:
#                                                Dialogue  \
# 0     [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# 1     [Speaker 1, Speaker 2: Hi, Speaker 3: Hi! Hey ...
# 2     [Speaker 1, Speaker 2: Hi!, Speaker 3: Hey!, S...
# 3     [Speaker 1: Wow! It looks like we got a lot of...
# 4     [Speaker 1: Now, Mom, everything's going fine,...
# ...                                                 ...
# 1783  [Speaker 1: Nice camoflauge man, for a minute ...
# 1784  [Speaker 1: Well, I'm sure you'll teach her a ...
# 1785  [Speaker 1: You know what? I can't even worry ...
# 1786  [Speaker 1: And cut. Hey, Butt Guy, what the h...
# 1787  [Speaker 1: Buon Giorno, Bella Phoebe!, Speake...
#
#                                               Relations Origin  \
# 0     [{'y': 'casting director', 'x': 'Ann', 'rid': ...    dev
# 1     [{'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [...    dev
# 2     [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r...    dev
# 3     [{'y': 'baby', 'x': 'Speaker 2', 'rid': [1], '...    dev
# 4     [{'y': '26', 'x': 'Speaker 1', 'rid': [2], 'r'...    dev
# ...                                                 ...    ...
# 1783  [{'y': 'Speaker 1', 'x': 'Speaker 2', 'rid': [...  train
# 1784  [{'y': 'Sir', 'x': 'Speaker 1', 'rid': [1], 'r...  train
# 1785  [{'y': 'baby', 'x': 'Speaker 1', 'rid': [1], '...  train
# 1786  [{'y': 'Butt Guy', 'x': 'Speaker 2', 'rid': [2...  train
# 1787  [{'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [...  train
#
#                                       PredictedEntities  \
# 0     [weeks:DATE, Ann:PERSON, Joey:PERSON, 7:CARDIN...
# 1     [1:CARDINAL, 2:CARDINAL, Jack:PERSON, 35 years...
# 2     [three:CARDINAL, Geller:PERSON, 1:CARDINAL, Em...
# 3     [1:CARDINAL, 2:CARDINAL, eight weeks:DATE, 3:C...
# 4           [only 26:CARDINAL, 1:CARDINAL, Ross:PERSON]
# ...                                                 ...
# 1783  [Chandler Bing:PERSON, Fourth:ORDINAL, 1:CARDI...
# 1784  [Bing:PERSON, 1:CARDINAL, Tuesday:DATE, Wednes...
# 1785  [2:CARDINAL, Rach:PERSON, 1:CARDINAL, shh shhh...
# 1786          [2:CARDINAL, Butt Guy:PERSON, 1:CARDINAL]
# 1787  [Bella Phoebe !:PERSON, 1:CARDINAL, 5:CARDINAL...
#
#                                       AnnotatedEntities  \
# 0     [Phoebe Buffay:PER, agent:STRING, Speaker 2:PE...
# 1     [Speaker 3:PER, Speaker 2:PER, Jack:PER, Speak...
# 2     [Emma:PER, Speaker 2:PER, man:STRING, Speaker ...
# 3     [Speaker 2:PER, Speaker 1:PER, Speaker 3:PER, ...
# 4                   [Ross:PER, Speaker 1:PER, 26:VALUE]
# ...                                                 ...
# 1783  [Speaker 2:PER, man:STRING, Speaker 1:PER, Sus...
# 1784  [Sir:STRING, Speaker 1:PER, Speaker 3:PER, Bin...
# 1785  [Rach:PER, Speaker 2:PER, Speaker 1:PER, littl...
# 1786                      [Speaker 2:PER, Butt Guy:PER]
# 1787  [Speaker 2:PER, Speaker 1:PER, Pheebs:PER, Spe...
#
#                           StandardizedAnnotatedEntities  Precision    Recall  \
# 0     [Phoebe Buffay:PERSON, agent:STRING, Speaker 2...   0.300000  0.461538
# 1     [Speaker 3:PERSON, Speaker 2:PERSON, Jack:PERS...   0.166667  0.250000
# 2     [Emma:PERSON, Speaker 2:PERSON, man:STRING, Sp...   0.200000  0.166667
# 3     [Speaker 2:PERSON, Speaker 1:PERSON, Speaker 3...   0.000000  0.000000
# 4          [Ross:PERSON, Speaker 1:PERSON, 26:CARDINAL]   0.333333  0.333333
# ...                                                 ...        ...       ...
# 1783  [Speaker 2:PERSON, man:STRING, Speaker 1:PERSO...   0.200000  0.400000
# 1784  [Sir:STRING, Speaker 1:PERSON, Speaker 3:PERSO...   0.111111  0.200000
# 1785  [Rach:PERSON, Speaker 2:PERSON, Speaker 1:PERS...   0.250000  0.200000
# 1786                [Speaker 2:PERSON, Butt Guy:PERSON]   0.333333  0.500000
# 1787  [Speaker 2:PERSON, Speaker 1:PERSON, Pheebs:PE...   0.083333  0.200000
#
#             F1                             MissingFromGroundTruth  \
# 0     0.363636  [weeks:DATE, 10:CARDINAL, Joey:PERSON, 1:CARDI...
# 1     0.200000  [1:CARDINAL, 2:CARDINAL, 35 years:DATE, 3:CARD...
# 2     0.181818  [three:CARDINAL, 1:CARDINAL, 5:CARDINAL, 2:CAR...
# 3     0.000000  [1:CARDINAL, 2:CARDINAL, eight weeks:DATE, 3:C...
# 4     0.333333                     [1:CARDINAL, only 26:CARDINAL]
# ...        ...                                                ...
# 1783  0.266667  [Fourth:ORDINAL, 1:CARDINAL, David Stein:PERSO...
# 1784  0.142857  [1:CARDINAL, Tuesday:DATE, Wednesday:DATE, 2:C...
# 1785  0.222222          [2:CARDINAL, 1:CARDINAL, shh shhh:PERSON]
# 1786  0.400000                           [2:CARDINAL, 1:CARDINAL]
# 1787  0.117647  [Bella Phoebe !:PERSON, 1:CARDINAL, 5:CARDINAL...
#
#                                  MissingFromPredictions  \
# 0     [agent:STRING, man:STRING, casting director:ST...
# 1     [Speaker 3:PERSON, Speaker 1:PERSON, Speaker 2...
# 2     [man:STRING, one:CARDINAL, Speaker 4:PERSON, S...
# 3     [Speaker 3:PERSON, Speaker 2:PERSON, roomie:ST...
# 4                       [Speaker 1:PERSON, 26:CARDINAL]
# ...                                                 ...
# 1783   [Speaker 1:PERSON, man:STRING, Speaker 2:PERSON]
# 1784  [Sir:STRING, Speaker 3:PERSON, Speaker 1:PERSO...
# 1785  [Speaker 1:PERSON, baby:STRING, Speaker 2:PERS...
# 1786                                 [Speaker 2:PERSON]
# 1787  [Speaker 6:PERSON, Speaker 2:PERSON, Pheebs:PE...
#
#                                      CorrectPredictions  \
# 0     [Ann:PERSON, Annie:PERSON, Estelle:PERSON, Joe...
# 1                                         [Jack:PERSON]
# 2                          [Geller:PERSON, Emma:PERSON]
# 3                                                    []
# 4                                         [Ross:PERSON]
# ...                                                 ...
# 1783          [Chandler Bing:PERSON, Susie Moss:PERSON]
# 1784                                      [Bing:PERSON]
# 1785                                      [Rach:PERSON]
# 1786                                  [Butt Guy:PERSON]
# 1787                                  [Racquela:PERSON]
#
#                                          SpacyDialogues
# 0     (Speaker, 1, :, Hey, !, \n, Speaker, 2, :, Hey...
# 1     (Speaker, 1, ,, Speaker, 2, :, Hi, \n, Speaker...
# 2     (Speaker, 1, ,, Speaker, 2, :, Hi, !, \n, Spea...
# 3     (Speaker, 1, :, Wow, !, It, looks, like, we, g...
# 4     (Speaker, 1, :, Now, ,, Mom, ,, everything, 's...
# ...                                                 ...
# 1783  (Speaker, 1, :, Nice, camoflauge, man, ,, for,...
# 1784  (Speaker, 1, :, Well, ,, I, 'm, sure, you, 'll...
# 1785  (Speaker, 1, :, You, know, what, ?, I, ca, n't...
# 1786  (Speaker, 1, :, And, cut, ., Hey, ,, Butt, Guy...
# 1787  (Speaker, 1, :, Buon, Giorno, ,, Bella, Phoebe...
#
# [1788 rows x 13 columns]

# %% [markdown]
# ## Goals of Notebook
# 1. Create entity distance metric
# 2. Create hobby keyword spotter

# %%
import spacy
from spacy.tokens import Span
from spacy.language import Language

# @Language.factory("custom_entity_recognizer")
# def create_custom_entity_recognizer(nlp, name):
#     return CustomEntityRecognizer(nlp)

class CustomEntityRecognizer:
    name = "custom_entity_recognizer"
    
    def __init__(self, nlp):
        self.nlp = nlp

    # def __call__(self, doc):
    #     # Use custom entities from doc.user_data if available, else use default list
    #     custom_entities = doc.user_data.get('custom_entities', [])
    #     matches = []
    #     doc.ents = []
    #     spans = list(doc.ents)

    #     for entity in custom_entities:
    #         if entity in doc.text:
    #             start_char = doc.text.index(entity)
    #             end_char = start_char + len(entity)
    #             # Convert character offsets to token offsets
    #             start = len([t for t in doc if t.idx < start_char])
    #             end = len([t for t in doc if t.idx < end_char])

    #             # Check for overlap with existing entities
    #             has_overlap = any([start <= existing.end and end >= existing.start for existing in spans])
    #             if not has_overlap:
    #                 span = Span(doc, start, end, label="CUSTOM_ENTITY")
    #                 matches.append(span)
    #                 spans.append(span)

    #     doc.ents = spans
    #     return doc
    def __call__(self, doc):
        # Use custom entities from doc.user_data if available, else use default list
        custom_entities = doc.user_data.get('custom_entities', [])
        matches = []
        doc.ents = []
        spans = list(doc.ents)
    
        for token in doc:
            if token.text == '\n':  # Replace this with the pattern that signifies a new sentence.
                token.is_sent_start = True
    
        for entity in custom_entities:
            if entity in doc.text:
                start_char = doc.text.index(entity)
                end_char = start_char + len(entity)
                # Convert character offsets to token offsets
                start = len([t for t in doc if t.idx < start_char])
                end = len([t for t in doc if t.idx < end_char])
    
                # Check for overlap with existing entities
                has_overlap = any([start <= existing.end and end >= existing.start for existing in spans])
                if not has_overlap:
                    span = Span(doc, start, end, label="CUSTOM_ENTITY")
                    matches.append(span)
                    spans.append(span)
    
        doc.ents = spans
        return doc

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('sentencizer')  # add sentencizer to the pipeline
nlp.add_pipe("custom_entity_recognizer", after="ner")

dialogue = '\n'.join(df2.Dialogue.iloc[2])
# Add your custom entities list here, which will be picked up by the pipeline
doc = nlp.make_doc(dialogue)
doc.user_data['custom_entities'] = ['Emma', 'Mrs. Geller', 'Speaker 1', 'dad', 'Speaker 4', 'Speaker 3', 'Speaker 5', 'man', 'Mr. Geller', 'Geller', 'one', 'Speaker 2']
nlp.get_pipe('custom_entity_recognizer')(doc)

from spacy import displacy

options = {"ents": ["CUSTOM_ENTITY"]}
displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Speaker 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Speaker 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# : Hi!</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Speaker 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# : Hey!</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Speaker 4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# : So glad you came!</br>Speaker 1: I can't believe
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
#  is already
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# !</br>Speaker 2: I remember your first birthday! Ross was jealous of all the attention we were giving you. He pulled on his testicles so hard! We had to take him to the emergency room!</br>Speaker 3: There's something you didn't know about your
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# !</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Speaker 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# : Hey Mr. and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mrs. Geller
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# ! Let me help you with that.</br>Speaker 1: Thank you!</br>Speaker 5: Oh
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CUSTOM_ENTITY</span>
# </mark>
# , this is great, uh? The three of us together again! You know what would be fun? If we gave this present to Emma from all of us!</br>Speaker 1: Which one are you?</div></span>

# %%
def overwrite_entities(dialogue, custom_entities):
    custom_entities = [e.split(':')[0] for e in custom_entities]
    nlp = spacy.load('en_core_web_sm')
    nlp.add_pipe('sentencizer')  # add sentencizer to the pipeline
    nlp.add_pipe("custom_entity_recognizer", after="ner")
    dialogue_str = "\\n".join(dialogue)
    doc = nlp.make_doc(dialogue_str)
    
    
    doc.user_data['custom_entities'] = custom_entities 
    nlp.get_pipe('custom_entity_recognizer')(doc)
    return doc

# %%
from tqmd import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 from tqmd import pandas
#
# ModuleNotFoundError: No module named 'tqmd'

# %%
tqdm.pandas()  # or tqdm_auto.pandas() for automatic notebook integration

# %%
df2['SpacyDialoguesCustom'] = df2.progress_apply(
    lambda row: 
        overwrite_entities(
            dialogue=row['Dialogue'],
            custom_entities=row['AnnotatedEntities']
        ), axis=1)
# Out:
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▊         | 1648/1788 [15:38<01:19,  1.76it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 df2['SpacyDialoguesCustom'] = df2.progress_apply(
#       2     lambda row:
#       3         overwrite_entities(
#       4             dialogue=row['Dialogue'],
#       5             custom_entities=row['AnnotatedEntities']
#       6         ), axis=1)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\tqdm\std.py:805, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     802 # Apply the provided function (in **kwargs)
#     803 # on the df using our wrapper (which provides bar updating)
#     804 try:
# --> 805     return getattr(df, df_function)(wrapper, **kwargs)
#     806 finally:
#     807     t.close()
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\tqdm\std.py:800, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     794 def wrapper(*args, **kwargs):
#     795     # update tbar correctly
#     796     # it seems `pandas apply` calls `func` twice
#     797     # on the first column/row to decide whether it can
#     798     # take a fast or slow code path; so stop when t.total==t.n
#     799     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 800     return func(*args, **kwargs)
#
# Cell In[150], line 3, in <lambda>(row)
#       1 df2['SpacyDialoguesCustom'] = df2.progress_apply(
#       2     lambda row:
# ----> 3         overwrite_entities(
#       4             dialogue=row['Dialogue'],
#       5             custom_entities=row['AnnotatedEntities']
#       6         ), axis=1)
#
# Cell In[134], line 3, in overwrite_entities(dialogue, custom_entities)
#       1 def overwrite_entities(dialogue, custom_entities):
#       2     custom_entities = [e.split(':')[0] for e in custom_entities]
# ----> 3     nlp = spacy.load('en_core_web_sm')
#       4     nlp.add_pipe('sentencizer')  # add sentencizer to the pipeline
#       5     nlp.add_pipe("custom_entity_recognizer", after="ner")
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#      57         disable=disable,
#      58         enable=enable,
#      59         exclude=exclude,
#      60         config=config,
#      61     )
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\util.py:442, in load_model(name, vocab, disable, enable, exclude, config)
#     440     return get_lang_class(name.replace("blank:", ""))()
#     441 if is_package(name):  # installed as package
# --> 442     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     443 if Path(name).exists():  # path to model data directory
#     444     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\util.py:478, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     461 """Load a model from an installed package.
#     462
#     463 name (str): The package name.
#    (...)
#     475 RETURNS (Language): The loaded nlp object.
#     476 """
#     477 cls = importlib.import_module(name)
# --> 478 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\en_core_web_sm\__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\util.py:659, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     657 if not model_path.exists():
#     658     raise IOError(Errors.E052.format(path=data_path))
# --> 659 return load_model_from_path(
#     660     data_path,
#     661     vocab=vocab,
#     662     meta=meta,
#     663     disable=disable,
#     664     enable=enable,
#     665     exclude=exclude,
#     666     config=config,
#     667 )
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\util.py:524, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     515 config = load_config(config_path, overrides=overrides)
#     516 nlp = load_model_from_config(
#     517     config,
#     518     vocab=vocab,
#    (...)
#     522     meta=meta,
#     523 )
# --> 524 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\language.py:2125, in Language.from_disk(self, path, exclude, overrides)
#    2122 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2123     # Convert to list here in case exclude is (default) tuple
#    2124     exclude = list(exclude) + ["vocab"]
# -> 2125 util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2126 self._path = path  # type: ignore[assignment]
#    2127 self._link_components()
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\util.py:1369, in from_disk(path, readers, exclude)
#    1366 for key, reader in readers.items():
#    1367     # Split to support file names like meta.json
#    1368     if key.split(".")[0] not in exclude:
# -> 1369         reader(path / key)
#    1370 return path
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\language.py:2101, in Language.from_disk.<locals>.deserialize_vocab(path)
#    2099 def deserialize_vocab(path: Path) -> None:
#    2100     if path.exists():
# -> 2101         self.vocab.from_disk(path, exclude=exclude)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\vocab.pyx:489, in spacy.vocab.Vocab.from_disk()
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\spacy\strings.pyx:267, in spacy.strings.StringStore.from_disk()
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\srsly\_json_api.py:53, in read_json(path)
#      51 file_path = force_path(path)
#      52 with file_path.open("r", encoding="utf8") as f:
# ---> 53     return ujson.load(f)
#
# ValueError: Could not reserve memory block

# %%
# [e.split(':')[0] for e in df2.iloc[0]['AnnotatedEntities']]
# custom_entities.iloc[0].ents

# %%
# Out:
# (Speaker 1,
#  2,
#  3,
#  man,
#  agent,
#  Estelle,
#  casting director,
#  Pheebs,
#  Katelynn,
#  Phoebe Buffay,
#  Ann,
#  Annie,
#  Joey Tribbiani)

# %%
df2['SpacyDialogueCustom']

# %%
# [print(f'd={d}') for d in doc]

# %%
import re
from itertools import combinations, permutations

class EntityCombiner:
    def __init__(self, doc, ignore_entity_types=None, entities=None, relations=None):
        if ignore_entity_types is None:
            ignore_entity_types = []
        self.doc = doc

        if entities is None:
            self.entities = [ent for ent in doc.ents if ent.label_ not in ignore_entity_types]
        else:
            self.entities = [entity for entity in entities]

        self.relations = relations

    def _calculate_turn_distance(self, pairs_generator):
        entity_turns = dict()
        current_turn = 0
        for sentence in self.doc.sents:
            if re.match(r'Speaker \d+:', sentence.text):
                current_turn += 1
            for entity in self.entities:
                if entity.start >= sentence.start and entity.end <= sentence.end:
                    entity_turns[entity] = current_turn
        entity_pairs = pairs_generator(self.entities, 2)
        entity_pairs_distance = [(pair[0], pair[1], abs(entity_turns.get(pair[0], 0) - entity_turns.get(pair[1], 0))) for pair in entity_pairs]
        return entity_pairs_distance

    def _calculate_word_distance(self, pairs_generator):
        entity_pairs = pairs_generator(self.entities, 2)
        entity_pairs_distance = [(pair[0], pair[1], abs(pair[0].start - pair[1].end)) for pair in entity_pairs]
        return entity_pairs_distance

    def get_entity_pairs(self, distance_type='turn', combination_type='combinations'):
        if distance_type == 'turn':
            if combination_type == 'combinations':
                return self._calculate_turn_distance(combinations)
            elif combination_type == 'permutations':
                return self._calculate_turn_distance(permutations)
            else:
                raise ValueError("Invalid combination_type. Supported values are 'combinations' and 'permutations'.")
        elif distance_type == 'word':
            if combination_type == 'combinations':
                return self._calculate_word_distance(combinations)
            elif combination_type == 'permutations':
                return self._calculate_word_distance(permutations)
            else:
                raise ValueError("Invalid combination_type. Supported values are 'combinations' and 'permutations'.")
        else:
            raise ValueError("Invalid distance_type. Supported values are 'turn' and 'word'.")

    def get_relation_tuples_old(self):
        """working"""
        relation_tuples = []
        for r in self.relations:
            x_entity = next((e for e in self.entities if e.text == r['x']), None)
            y_entity = next((e for e in self.entities if e.text == r['y']), None)
            if x_entity and y_entity:
                turn_distance = abs(x_entity.start - y_entity.start)
                # the start of the first entity and the end of the second entity
                word_distance_start = abs(x_entity.start - y_entity.end)
                # the end of the first entity and the start of the second entity
                word_distance_end = abs(x_entity.end - y_entity.start)
                relation_tuples.append({
                    'x': x_entity.text,
                    'y': y_entity.text, 
                    'turn_distance':turn_distance,
                    "word_distance_start": word_distance_start,
                    "word_distance_end": word_distance_end, 
                    "r": r['r'][0]
                })
        return relation_tuples
    
    def get_entity_tuples(self, combination_type='combinations'):
        """not working"""
        entity_tuples = []
        entity_pairs_turn = self.get_entity_pairs(distance_type='turn', combination_type=combination_type)
        entity_pairs_word = self.get_entity_pairs(distance_type='word', combination_type=combination_type)

        for pair_turn in entity_pairs_turn:
            pair_word = next((pair for pair in entity_pairs_word if (pair[0] == pair_turn[0] and pair[1] == pair_turn[1]) or (pair[0] == pair_turn[1] and pair[1] == pair_turn[0])), None)
            if pair_word:
                turn_distance = pair_turn[2]
                word_distance = pair_word[2]
            else:
                turn_distance = None
                word_distance = None
            entity_tuples.append({
                'x': pair_turn[0].text,
                'y': pair_turn[1].text, 
                'turn_distance': turn_distance,
                'word_distance': word_distance,
            })
        return entity_tuples
        
    def get_relation_tuples(self, combination_type='combinations'):
        """not working"""
        relation_tuples = []
        entity_pairs_turn = self.get_entity_pairs(distance_type='turn', combination_type=combination_type)
        entity_pairs_word = self.get_entity_pairs(distance_type='word', combination_type=combination_type)
        for r in self.relations:
            x_entity = next((e for e in self.entities if e.text == r['x']), None)
            y_entity = next((e for e in self.entities if e.text == r['y']), None)
            if x_entity and y_entity:
                # find the pair with x_entity and y_entity for turn distance
                pair_turn = next((pair for pair in entity_pairs_turn if (pair[0] == x_entity and pair[1] == y_entity) or (pair[0] == y_entity and pair[1] == x_entity)), None)
                # find the pair with x_entity and y_entity for word distance
                pair_word = next((pair for pair in entity_pairs_word if (pair[0] == x_entity and pair[1] == y_entity) or (pair[0] == y_entity and pair[1] == x_entity)), None)
                if pair_turn and pair_word:
                    turn_distance = pair_turn[2]
                    word_distance = pair_word[2]
                else:
                    turn_distance = None
                    word_distance = None

                r['turn_distance'] = turn_distance
                r['word_distance'] = word_distance
                
                print("\nr=",r)
                print("relation_tuples=",relation_tuples)
                
                relation_tuples.append(r)
        return relation_tuples



# displacy.render(doc, style="ent", options=options, jupyter=True)
ec = EntityCombiner(doc, ignore_entity_types=['CARDINAL'], relations=df2.iloc[2].Relations)
entity_tuples = ec.get_relation_tuples()
entity_tuples
# Out:
# r= {'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}
# relation_tuples= []
#
# r= {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}]
#
# r= {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}]
#
# r= {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}]
#
# r= {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}]
#
# r= {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}]
#
# r= {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}]
#
# r= {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}]
#
# r= {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}]
#
# r= {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}]
#
# r= {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}]
#
# r= {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}]
#
# r= {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}]
#
# r= {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}]
#
# r= {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}]
#
# r= {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}]
#
# r= {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}]
#
# r= {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}]
#
# r= {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 11}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}]
#
# r= {'y': 'dad', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 11}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 11}]
#
# r= {'y': 'Mrs. Geller', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 11}, {'y': 'dad', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 11}]
#
# r= {'y': 'Speaker 2', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 11}, {'y': 'dad', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 11}, {'y': 'Mrs. Geller', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}]
#
# r= {'y': 'Emma', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 17}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 11}, {'y': 'dad', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 11}, {'y': 'Mrs. Geller', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 2', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}]
#
# r= {'y': 'Speaker 2', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 14}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 11}, {'y': 'dad', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 11}, {'y': 'Mrs. Geller', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 2', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Emma', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 17}]
#
# ...
#
# r= {'y': 'Emma', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}
# relation_tuples= [{'y': 'man', 'x': 'Speaker 4', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 106}, {'y': 'one', 'x': 'Speaker 4', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 20}, {'y': 'Speaker 3', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'one', 'x': 'Emma', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 4}, {'y': 'Speaker 4', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 85}, {'y': 'Speaker 2', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'Speaker 3', 'x': 'Mrs. Geller', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Mrs. Geller', 'x': 'Speaker 2', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 97}, {'y': 'man', 'x': 'Speaker 1', 'rid': [2], 'r': ['with_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 121}, {'y': 'Mrs. Geller', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Emma', 'x': 'Speaker 3', 'rid': [2], 'r': ['with_relation'], 't': ['dad'], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 23}, {'y': 'man', 'x': 'Speaker 3', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 112}, {'y': 'dad', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 5}, {'y': 'man', 'x': 'Speaker 5', 'rid': [1], 'r': ['unanswerable'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 2', 'x': 'Emma', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 29}, {'y': 'Speaker 4', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Speaker 2', 'x': 'Speaker 5', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 91}, {'y': 'Speaker 4', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 3', 'x': 'Speaker 1', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 11}, {'y': 'dad', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'STRING', 'turn_distance': 0, 'word_distance': 11}, {'y': 'Mrs. Geller', 'x': 'Mrs. Geller', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': None, 'word_distance': None}, {'y': 'Speaker 2', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 8}, {'y': 'Emma', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 17}, {'y': 'Speaker 2', 'x': 'Speaker 4', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'PER', 'turn_distance': 0, 'word_distance': 14}, {'y': 'one', 'x': 'Speaker 3', 'rid': [0], 'r': ['no_relation'], 't': [''], 'x_type': 'PER', 'y_type': 'VALUE', 'turn_distance': 0, 'word_distance': 26}, {'y': 'man', 'x': 'Mrs. Geller', 'ri ...
# [{'y': 'man',
#   'x': 'Speaker 4',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 106},
#  {'y': 'one',
#   'x': 'Speaker 4',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 20},
#  {'y': 'Speaker 3',
#   'x': 'Emma',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['dad'],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 23},
#  {'y': 'one',
#   'x': 'Emma',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 4},
#  {'y': 'Speaker 4',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 85},
#  {'y': 'Speaker 2',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 97},
#  {'y': 'Speaker 3',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 91},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 97},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 121},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 91},
#  {'y': 'Emma',
#   'x': 'Speaker 3',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['dad'],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 23},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 112},
#  {'y': 'dad',
#   'x': 'Speaker 5',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 5},
#  {'y': 'man',
#   'x': 'Speaker 5',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 29},
#  {'y': 'Speaker 2',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 29},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 91},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 11},
#  {'y': 'dad',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 11},
#  {'y': 'Mrs. Geller',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'Emma',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 17},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 14},
#  {'y': 'one',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 26},
#  {'y': 'man',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 23},
#  {'y': 'dad',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 87},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 85},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 118},
#  {'y': 'Emma',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 69},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 14},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'one',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 66},
#  {'y': 'Emma',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 29},
#  {'y': 'Emma',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 63},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'dad',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 90},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 100},
#  {'y': 'one',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 32},
#  {'y': 'one',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 60},
#  {'y': 'dad',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 59},
#  {'y': 'Mrs. Geller',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 69},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 17},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'man',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 90},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'Emma',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 32},
#  {'y': 'Speaker 4',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 17},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 5},
#  {'y': 'dad',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 81},
#  {'y': 'one',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 35},
#  {'y': 'dad',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 75},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 79},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 85},
#  {'y': 'Emma',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None}]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df2['SpacyDialogues'] = docs
#
# NameError: name 'docs' is not defined

# %%
entity_tuples
# Out:
# [{'y': 'man',
#   'x': 'Speaker 4',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 106},
#  {'y': 'one',
#   'x': 'Speaker 4',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 20},
#  {'y': 'Speaker 3',
#   'x': 'Emma',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['dad'],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 23},
#  {'y': 'one',
#   'x': 'Emma',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 4},
#  {'y': 'Speaker 4',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 85},
#  {'y': 'Speaker 2',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 97},
#  {'y': 'Speaker 3',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 91},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 97},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 121},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 91},
#  {'y': 'Emma',
#   'x': 'Speaker 3',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['dad'],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 23},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 112},
#  {'y': 'dad',
#   'x': 'Speaker 5',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 5},
#  {'y': 'man',
#   'x': 'Speaker 5',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 29},
#  {'y': 'Speaker 2',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 29},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 91},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 11},
#  {'y': 'dad',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 11},
#  {'y': 'Mrs. Geller',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'Emma',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 17},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 14},
#  {'y': 'one',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 26},
#  {'y': 'man',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 23},
#  {'y': 'dad',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 87},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 85},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 118},
#  {'y': 'Emma',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 69},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 14},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'one',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 66},
#  {'y': 'Emma',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 29},
#  {'y': 'Emma',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 63},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None},
#  {'y': 'dad',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 90},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 100},
#  {'y': 'one',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 32},
#  {'y': 'one',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 60},
#  {'y': 'dad',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 59},
#  {'y': 'Mrs. Geller',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 69},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 17},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'man',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 90},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 8},
#  {'y': 'Emma',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 32},
#  {'y': 'Speaker 4',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 17},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 5},
#  {'y': 'dad',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 81},
#  {'y': 'one',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE',
#   'turn_distance': 0,
#   'word_distance': 35},
#  {'y': 'dad',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING',
#   'turn_distance': 0,
#   'word_distance': 75},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 79},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': 0,
#   'word_distance': 85},
#  {'y': 'Emma',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER',
#   'turn_distance': None,
#   'word_distance': None}]

# %%
df2['EnrichedRelations'] = entity_tuples
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df2['EnrichedRelations'] = entity_tuples
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\.virtualenvs\RelNetCare-pBkonNa4\lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (56) does not match length of index (1788)

# %%
# Out:
# [{'y': 'man',
#   'x': 'Speaker 4',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'one',
#   'x': 'Speaker 4',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE'},
#  {'y': 'Speaker 3',
#   'x': 'Emma',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['dad'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'one',
#   'x': 'Emma',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE'},
#  {'y': 'Speaker 4',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 3',
#   'x': 'Mrs. Geller',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mr. Geller',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Geller',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Emma',
#   'x': 'Speaker 3',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['dad'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'dad',
#   'x': 'Speaker 5',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 5',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Geller',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'dad',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Mrs. Geller',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Emma',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mr. Geller',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'one',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE'},
#  {'y': 'man',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Geller',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'dad',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Geller',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mr. Geller',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Emma',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mr. Geller',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'one',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE'},
#  {'y': 'Emma',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Emma',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'dad',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'one',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE'},
#  {'y': 'one',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE'},
#  {'y': 'Mr. Geller',
#   'x': 'Mrs. Geller',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'dad',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Geller',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mrs. Geller',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mr. Geller',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Mr. Geller',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Geller',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 3',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Emma',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 4',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'dad',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Geller',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'one',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'VALUE'},
#  {'y': 'dad',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 4',
#   'x': 'Speaker 5',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Mrs. Geller',
#   'x': 'Speaker 4',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Emma',
#   'x': 'Emma',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'}]

# %%
print(nlp.pipe_names)  # It should print something like ['tok2vec', 'tagger', 'parser', 'ner']
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner', 'custom_entity_recognizer', 'sentencizer']

# %%
# nlp.add_pipe('sentencizer')
doc = nlp.make_doc(dialogue)
doc.user_data['custom_entities'] = ['Emma', 'Mrs. Geller', 'Speaker 1', 'dad', 'Speaker 4', 'Speaker 3', 'Speaker 5', 'man', 'Mr. Geller', 'Geller', 'one', 'Speaker 2']
nlp.get_pipe('custom_entity_recognizer')(doc)

# [x for x in doc.sents]
# Out:
# Speaker 1, Speaker 2: Hi!
# Speaker 3: Hey!
# Speaker 4: So glad you came!
# Speaker 1: I can't believe Emma is already one!
# Speaker 2: I remember your first birthday! Ross was jealous of all the attention we were giving you. He pulled on his testicles so hard! We had to take him to the emergency room!
# Speaker 3: There's something you didn't know about your dad!
# Speaker 5: Hey Mr. and Mrs. Geller! Let me help you with that.
# Speaker 1: Thank you!
# Speaker 5: Oh man, this is great, uh? The three of us together again! You know what would be fun? If we gave this present to Emma from all of us!
# Speaker 1: Which one are you?

# %%
df2_relations = df2.iloc[2].Relations

other_list = ec.get_relation_tuples()

missing_items = []

for item1 in df2_relations:
    found = False
    for item2 in other_list:
        if item1['x'] == item2['x'] and item1['y'] == item2['y'] and item1['r'][0] == item2['r']:
            found = True
            break
    if not found:
        missing_items.append(item1)

print(missing_items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 3
#       1 df2_relations = df2.iloc[2].Relations
# ----> 3 other_list = ec.get_relation_tuples()
#       5 missing_items = []
#       7 for item1 in df2_relations:
#
# Cell In[67], line 80, in EntityCombiner.get_relation_tuples(self, combination_type)
#      78 entity_pairs_turn = self.get_entity_pairs(distance_type='turn', combination_type=combination_type)
#      79 entity_pairs_word = self.get_entity_pairs(distance_type='word', combination_type=combination_type)
# ---> 80 for r in self.relations:
#      81     x_entity = next((e for e in self.entities if e.text == r['x']), None)
#      82     y_entity = next((e for e in self.entities if e.text == r['y']), None)
#
# TypeError: 'NoneType' object is not iterable

# %%
unique_entities = df2.AnnotatedEntities.apply(lambda x: [e.split(':')[0] for e in x]).iloc[0]
unique_entities

ec = EntityCombiner(d, ignore_entity_types=['CARDINAL'], entities=doc.ents)
ec.get_entity_pairs(distance_type='turn', combination_type='permutations')
# Out:
# [(Speaker 1, Speaker 2, 0),
#  (Speaker 1, Speaker 3, 0),
#  (Speaker 1, Speaker 4, 0),
#  (Speaker 1, Emma, 0),
#  (Speaker 1, one, 0),
#  (Speaker 1, dad, 1),
#  (Speaker 1, Speaker 5, 1),
#  (Speaker 1, Mrs. Geller, 1),
#  (Speaker 1, man, 2),
#  (Speaker 2, Speaker 1, 0),
#  (Speaker 2, Speaker 3, 0),
#  (Speaker 2, Speaker 4, 0),
#  (Speaker 2, Emma, 0),
#  (Speaker 2, one, 0),
#  (Speaker 2, dad, 1),
#  (Speaker 2, Speaker 5, 1),
#  (Speaker 2, Mrs. Geller, 1),
#  (Speaker 2, man, 2),
#  (Speaker 3, Speaker 1, 0),
#  (Speaker 3, Speaker 2, 0),
#  (Speaker 3, Speaker 4, 0),
#  (Speaker 3, Emma, 0),
#  (Speaker 3, one, 0),
#  (Speaker 3, dad, 1),
#  (Speaker 3, Speaker 5, 1),
#  (Speaker 3, Mrs. Geller, 1),
#  (Speaker 3, man, 2),
#  (Speaker 4, Speaker 1, 0),
#  (Speaker 4, Speaker 2, 0),
#  (Speaker 4, Speaker 3, 0),
#  (Speaker 4, Emma, 0),
#  (Speaker 4, one, 0),
#  (Speaker 4, dad, 1),
#  (Speaker 4, Speaker 5, 1),
#  (Speaker 4, Mrs. Geller, 1),
#  (Speaker 4, man, 2),
#  (Emma, Speaker 1, 0),
#  (Emma, Speaker 2, 0),
#  (Emma, Speaker 3, 0),
#  (Emma, Speaker 4, 0),
#  (Emma, one, 0),
#  (Emma, dad, 1),
#  (Emma, Speaker 5, 1),
#  (Emma, Mrs. Geller, 1),
#  (Emma, man, 2),
#  (one, Speaker 1, 0),
#  (one, Speaker 2, 0),
#  (one, Speaker 3, 0),
#  (one, Speaker 4, 0),
#  (one, Emma, 0),
#  (one, dad, 1),
#  (one, Speaker 5, 1),
#  (one, Mrs. Geller, 1),
#  (one, man, 2),
#  (dad, Speaker 1, 1),
#  (dad, Speaker 2, 1),
#  (dad, Speaker 3, 1),
#  (dad, Speaker 4, 1),
#  (dad, Emma, 1),
#  (dad, one, 1),
#  (dad, Speaker 5, 0),
#  (dad, Mrs. Geller, 0),
#  (dad, man, 1),
#  (Speaker 5, Speaker 1, 1),
#  (Speaker 5, Speaker 2, 1),
#  (Speaker 5, Speaker 3, 1),
#  (Speaker 5, Speaker 4, 1),
#  (Speaker 5, Emma, 1),
#  (Speaker 5, one, 1),
#  (Speaker 5, dad, 0),
#  (Speaker 5, Mrs. Geller, 0),
#  (Speaker 5, man, 1),
#  (Mrs. Geller, Speaker 1, 1),
#  (Mrs. Geller, Speaker 2, 1),
#  (Mrs. Geller, Speaker 3, 1),
#  (Mrs. Geller, Speaker 4, 1),
#  (Mrs. Geller, Emma, 1),
#  (Mrs. Geller, one, 1),
#  (Mrs. Geller, dad, 0),
#  (Mrs. Geller, Speaker 5, 0),
#  (Mrs. Geller, man, 1),
#  (man, Speaker 1, 2),
#  (man, Speaker 2, 2),
#  (man, Speaker 3, 2),
#  (man, Speaker 4, 2),
#  (man, Emma, 2),
#  (man, one, 2),
#  (man, dad, 1),
#  (man, Speaker 5, 1),
#  (man, Mrs. Geller, 1)]

# %%
df2.Relations.iloc[0]
# Out:
# [{'y': 'casting director',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Annie',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['agent'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Annie',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'casting director',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'agent',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'}]

# %%
entity_combiner = EntityCombiner(d, ignore_entity_types=['CARDINAL'])
entity_pairs = entity_combiner.get_entity_pairs(distance_type='turn', combination_type='combinations')
print("Combinations:")
print(entity_pairs)

entity_pairs = entity_combiner.get_entity_pairs(distance_type='turn', combination_type='permutations')
print("Permutations:")
print(entity_pairs)
# Out:
# Combinations:
# [(today, first, 0), (today, weeks, 0), (today, Chandler, 4), (today, Estelle, 9), (today, Katelynn, 13), (today, Phoebe Buffay's, 13), (today, Ann, 13), (today, Phoebe, 13), (today, Annie, 14), (today, Joey Tribbiani, 14), (today, Estelle, 14), (today, Joey, 15), (today, Estelle, 15), (today, Annie, 15), (first, weeks, 0), (first, Chandler, 4), (first, Estelle, 9), (first, Katelynn, 13), (first, Phoebe Buffay's, 13), (first, Ann, 13), (first, Phoebe, 13), (first, Annie, 14), (first, Joey Tribbiani, 14), (first, Estelle, 14), (first, Joey, 15), (first, Estelle, 15), (first, Annie, 15), (weeks, Chandler, 4), (weeks, Estelle, 9), (weeks, Katelynn, 13), (weeks, Phoebe Buffay's, 13), (weeks, Ann, 13), (weeks, Phoebe, 13), (weeks, Annie, 14), (weeks, Joey Tribbiani, 14), (weeks, Estelle, 14), (weeks, Joey, 15), (weeks, Estelle, 15), (weeks, Annie, 15), (Chandler, Estelle, 5), (Chandler, Katelynn, 9), (Chandler, Phoebe Buffay's, 9), (Chandler, Ann, 9), (Chandler, Phoebe, 9), (Chandler, Annie, 10), (Chandler, Joey Tribbiani, 10), (Chandler, Estelle, 10), (Chandler, Joey, 11), (Chandler, Estelle, 11), (Chandler, Annie, 11), (Estelle, Katelynn, 4), (Estelle, Phoebe Buffay's, 4), (Estelle, Ann, 4), (Estelle, Phoebe, 4), (Estelle, Annie, 5), (Estelle, Joey Tribbiani, 5), (Estelle, Estelle, 5), (Estelle, Joey, 6), (Estelle, Estelle, 6), (Estelle, Annie, 6), (Katelynn, Phoebe Buffay's, 0), (Katelynn, Ann, 0), (Katelynn, Phoebe, 0), (Katelynn, Annie, 1), (Katelynn, Joey Tribbiani, 1), (Katelynn, Estelle, 1), (Katelynn, Joey, 2), (Katelynn, Estelle, 2), (Katelynn, Annie, 2), (Phoebe Buffay's, Ann, 0), (Phoebe Buffay's, Phoebe, 0), (Phoebe Buffay's, Annie, 1), (Phoebe Buffay's, Joey Tribbiani, 1), (Phoebe Buffay's, Estelle, 1), (Phoebe Buffay's, Joey, 2), (Phoebe Buffay's, Estelle, 2), (Phoebe Buffay's, Annie, 2), (Ann, Phoebe, 0), (Ann, Annie, 1), (Ann, Joey Tribbiani, 1), (Ann, Estelle, 1), (Ann, Joey, 2), (Ann, Estelle, 2), (Ann, Annie, 2), (Phoebe, Annie, 1), (Phoebe, Joey Tribbiani, 1), (Phoebe, Estelle, 1), (Phoebe, Joey, 2), (Phoebe, Estelle, 2), (Phoebe, Annie, 2), (Annie, Joey Tribbiani, 0), (Annie, Estelle, 0), (Annie, Joey, 1), (Annie, Estelle, 1), (Annie, Annie, 1), (Joey Tribbiani, Estelle, 0), (Joey Tribbiani, Joey, 1), (Joey Tribbiani, Estelle, 1), (Joey Tribbiani, Annie, 1), (Estelle, Joey, 1), (Estelle, Estelle, 1), (Estelle, Annie, 1), (Joey, Estelle, 0), (Joey, Annie, 0), (Estelle, Annie, 0)]
# Permutations:
# [(today, first, 0), (today, weeks, 0), (today, Chandler, 4), (today, Estelle, 9), (today, Katelynn, 13), (today, Phoebe Buffay's, 13), (today, Ann, 13), (today, Phoebe, 13), (today, Annie, 14), (today, Joey Tribbiani, 14), (today, Estelle, 14), (today, Joey, 15), (today, Estelle, 15), (today, Annie, 15), (first, today, 0), (first, weeks, 0), (first, Chandler, 4), (first, Estelle, 9), (first, Katelynn, 13), (first, Phoebe Buffay's, 13), (first, Ann, 13), (first, Phoebe, 13), (first, Annie, 14), (first, Joey Tribbiani, 14), (first, Estelle, 14), (first, Joey, 15), (first, Estelle, 15), (first, Annie, 15), (weeks, today, 0), (weeks, first, 0), (weeks, Chandler, 4), (weeks, Estelle, 9), (weeks, Katelynn, 13), (weeks, Phoebe Buffay's, 13), (weeks, Ann, 13), (weeks, Phoebe, 13), (weeks, Annie, 14), (weeks, Joey Tribbiani, 14), (weeks, Estelle, 14), (weeks, Joey, 15), (weeks, Estelle, 15), (weeks, Annie, 15), (Chandler, today, 4), (Chandler, first, 4), (Chandler, weeks, 4), (Chandler, Estelle, 5), (Chandler, Katelynn, 9), (Chandler, Phoebe Buffay's, 9), (Chandler, Ann, 9), (Chandler, Phoebe, 9), (Chandler, Annie, 10), (Chandler, Joey Tribbiani, 10), (Chandler, Estelle, 10), (Chandler, Joey, 11), (Chandler, Estelle, 11), (Chandler, Annie, 11), (Estelle, today, 9), (Estelle, first, 9), (Estelle, weeks, 9), (Estelle, Chandler, 5), (Estelle, Katelynn, 4), (Estelle, Phoebe Buffay's, 4), (Estelle, Ann, 4), (Estelle, Phoebe, 4), (Estelle, Annie, 5), (Estelle, Joey Tribbiani, 5), (Estelle, Estelle, 5), (Estelle, Joey, 6), (Estelle, Estelle, 6), (Estelle, Annie, 6), (Katelynn, today, 13), (Katelynn, first, 13), (Katelynn, weeks, 13), (Katelynn, Chandler, 9), (Katelynn, Estelle, 4), (Katelynn, Phoebe Buffay's, 0), (Katelynn, Ann, 0), (Katelynn, Phoebe, 0), (Katelynn, Annie, 1), (Katelynn, Joey Tribbiani, 1), (Katelynn, Estelle, 1), (Katelynn, Joey, 2), (Katelynn, Estelle, 2), (Katelynn, Annie, 2), (Phoebe Buffay's, today, 13), (Phoebe Buffay's, first, 13), (Phoebe Buffay's, weeks, 13), (Phoebe Buffay's, Chandler, 9), (Phoebe Buffay's, Estelle, 4), (Phoebe Buffay's, Katelynn, 0), (Phoebe Buffay's, Ann, 0), (Phoebe Buffay's, Phoebe, 0), (Phoebe Buffay's, Annie, 1), (Phoebe Buffay's, Joey Tribbiani, 1), (Phoebe Buffay's, Estelle, 1), (Phoebe Buffay's, Joey, 2), (Phoebe Buffay's, Estelle, 2), (Phoebe Buffay's, Annie, 2), (Ann, today, 13), (Ann, first, 13), (Ann, weeks, 13), (Ann, Chandler, 9), (Ann, Estelle, 4), (Ann, Katelynn, 0), (Ann, Phoebe Buffay's, 0), (Ann, Phoebe, 0), (Ann, Annie, 1), (Ann, Joey Tribbiani, 1), (Ann, Estelle, 1), (Ann, Joey, 2), (Ann, Estelle, 2), (Ann, Annie, 2), (Phoebe, today, 13), (Phoebe, first, 13), (Phoebe, weeks, 13), (Phoebe, Chandler, 9), (Phoebe, Estelle, 4), (Phoebe, Katelynn, 0), (Phoebe, Phoebe Buffay's, 0), (Phoebe, Ann, 0), (Phoebe, Annie, 1), (Phoebe, Joey Tribbiani, 1), (Phoebe, Estelle, 1), (Phoebe, Joey, 2), (Phoebe, Estelle, 2), (Phoebe, Annie, 2), (Annie, today, 14), (Annie, first, 14), (Annie, weeks, 14), (Annie, Chandler, 10), (Annie, Estelle, 5), (Annie, Katelynn, 1), (Annie, Phoebe Buffay's, 1), (Annie, Ann, 1), (Annie, Phoebe, 1), (Annie, Joey Tribbiani, 0), (Annie, Estelle, 0), (Annie, Joey, 1), (Annie, Estelle, 1), (Annie, Annie, 1), (Joey Tribbiani, today, 14), (Joey Tribbiani, first, 14), (Joey Tribbiani, weeks, 14), (Joey Tribbiani, Chandler, 10), (Joey Tribbiani, Estelle, 5), (Joey Tribbiani, Katelynn, 1), (Joey Tribbiani, Phoebe Buffay's, 1), (Joey Tribbiani, Ann, 1), (Joey Tribbiani, Phoebe, 1), (Joey Tribbiani, Annie, 0), (Joey Tribbiani, Estelle, 0), (Joey Tribbiani, Joey, 1), (Joey Tribbiani, Estelle, 1), (Joey Tribbiani, Annie, 1), (Estelle, today, 14), (Estelle, first, 14), (Estelle, weeks, 14), (Estelle, Chandler, 10), (Estelle, Estelle, 5), (Estelle, Katelynn, 1), (Estelle, Phoebe Buffay's, 1), (Estelle, Ann, 1), (Estelle, Phoebe, 1), (Estelle, Annie, 0), (Estelle, Joey Tribbiani, 0), (Estelle, Joey, 1), (Estelle, Estelle, 1), (Estelle, Annie, 1), (Joey, today, 15), (Joey, first, 15 ...

# %%
df2.Relations.iloc[0]
# Out:
# [{'y': 'casting director',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Annie',
#   'x': 'Ann',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Estelle',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['agent'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 2',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Annie',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 3',
#   'rid': [1],
#   'r': ['unanswerable'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': ['friends'],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 1',
#   'rid': [2],
#   'r': ['with_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 2',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Speaker 1',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Pheebs',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 2',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'agent',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'casting director',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'agent',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Katelynn',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Joey Tribbiani',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'casting director',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'man',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Estelle',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Speaker 1',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'man',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'STRING'},
#  {'y': 'Pheebs',
#   'x': 'Ann',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Annie',
#   'x': 'Speaker 2',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Annie',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Katelynn',
#   'x': 'Speaker 3',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'},
#  {'y': 'Phoebe Buffay',
#   'x': 'Speaker 1',
#   'rid': [0],
#   'r': ['no_relation'],
#   't': [''],
#   'x_type': 'PER',
#   'y_type': 'PER'}]

# %%
df2.CorrectPredictions0]
# Out:
# ['Katelynn:PERSON',
#  'Estelle:PERSON',
#  'Joey Tribbiani:PERSON',
#  'Annie:PERSON',
#  'Ann:PERSON',
#  'Phoebe Buffay:PERSON']

# %%
df2.apply(lambda row: [(r['x'], r['y'], r['r'][0]) 
                       for r in row['Relations'] 
                       if (r['x'] in [cp.split(':')[0] for cp in row['CorrectPredictions']] 
                           and r['y'] in [cp.split(':')[0] for cp in row['CorrectPredictions']])], 
                       axis=1).explode().value_counts()Q
# Out:
# (Ross, Ross, no_relation)                 61
# (Rachel, Rachel, no_relation)             58
# (Chandler, Chandler, no_relation)         47
# (Monica, Monica, no_relation)             47
# (Joey, Joey, no_relation)                 36
#                                           ..
# (Egypt, Egypt, no_relation)                1
# (Pete, Richard, no_relation)               1
# (Richard, Pete, no_relation)               1
# (Phoebe, Phoebe Buffay, with_relation)     1
# (Nancy, Nancy, no_relation)                1
# Length: 1471, dtype: int64

# %%
df2.Relations.explode().apply( lambda x: x['r'][0])
# Out:
# 0       with_relation
# 0       with_relation
# 0       with_relation
# 0       with_relation
# 0       with_relation
#             ...
# 1787      no_relation
# 1787      no_relation
# 1787      no_relation
# 1787      no_relation
# 1787      no_relation
# Name: Relations, Length: 26238, dtype: object

# %%
get_counts_and_percentages(pd.DataFrame(df2.Relations.explode().apply( lambda x: x['r'][0])), cols=['Relations'])
# Out:
#                Counts     %
# Relations
# no_relation     16489  62.8
# with_relation    7650  29.2
# unanswerable     2099   8.0

# %%
get_counts_and_percentages(pd.DataFrame(df2.apply(lambda row: [(0, r['r'][0]) 
                       for r in row['Relations'] 
                       if (r['x'] in [cp.split(':')[0] for cp in row['CorrectPredictions']] 
                           and r['y'] in [cp.split(':')[0] for cp in row['CorrectPredictions']])], 
                       axis=1).explode().rename('Relations')), cols=['Relations'])


#.value_counts()
# Out:
#                     Counts     %
# Relations
# (0, no_relation)      1995  84.7
# (0, with_relation)     357  15.2
# (0, unanswerable)        3   0.1

# %%
displacy.render(d, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Hey!</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Hey.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Hey, man. What's up?</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Maybe you can tell me. My agent would like to know why I didn't show up at the audition I didn't know I had
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  good thing she gets me in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . How could you not give me the message?!</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Well, I'll tell ya I do enjoy guilt, but, ah, it wasn't me.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Yes, it was! It was him! Uh huh! Okay, it was me!</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : How is it you?</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Well, it was just, it was all so crazy, you know. I mean,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chandler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was in the closet, counting to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , and he was up to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and I hadn't found a place to hide yet. I-I-I meant to tell you, and I wrote it all down on my hand. See, all of it.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Yep, that's my audition.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : See, now this is why I keep notepads everywhere.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Yep, and that's why we don't invite you to play.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : What is the great tragedy here? You go get yourself another appointment.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Well,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Estelle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tried, you know. The casting director told her that I missed my chance.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : That is unfair. I'll call her and tell her it was totally my fault.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# : Pheebs, you can't do that. The casting director doesn't talk to friends, she only talks to agents.</br>Speaker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6

# %%
ignore_entity_types=['CARDINAL']
entities = set([ent for ent in d.ents if ent.label_ not in ignore_entity_types]) 
len(entities), entities
# Out:
# (15,
#  {today,
#   first,
#   weeks,
#   Chandler,
#   Estelle,
#   Katelynn,
#   Phoebe Buffay's,
#   Ann,
#   Phoebe,
#   Annie,
#   Joey Tribbiani,
#   Estelle,
#   Joey,
#   Estelle,
#   Annie})

# %%
def extract_hobbies(doc):
    # List of common hobbies
    hobby_list = [
        'reading', 'writing', 'sports', 'music', 'cooking', 'painting', 'dancing', 'hiking', 'fishing', 
        'gardening', 'photography', 'knitting', 'sewing', 'drawing', 'crafts', 'cycling', 'baking', 'swimming', 
        'camping', 'pottery', 'yoga', 'martial arts', 'singing', 'rock climbing', 'horse riding', 'bird watching', 
        'stamp collecting', 'jewelry making', 'playing guitar', 'playing piano', 'playing violin', 
        'video games', 'board games', 'card games', 'running', 'weightlifting', 'woodworking', 'scrapbooking', 
        'calligraphy', 'quilting', 'embroidery', 'crocheting', 'crossword puzzles', 'jigsaw puzzles', 
        'roller skating', 'skateboarding', 'soccer', 'football', 'basketball', 'tennis', 'golf', 'volleyball', 
        'rugby', 'skiing', 'snowboarding', 'ice skating', 'origami', 'magic', 'acting', 'theatre', 'comedy',
        'traveling', 'cinema', 'astronomy', 'chess', 'billiards', 'snooker', 'poker', 'brewing beer', 'winemaking',
        'blogging', 'podcasting', 'streaming', 'collecting', 'fashion', 'makeup', 'cosplay', 'meditation', 
        'learning languages', 'genealogy', 'archery', 'fencing', 'sailing', 'canoeing', 'kayaking', 'windsurfing', 
        'surfing', 'scuba diving', 'drone racing', 'kart racing', 'drone photography'
    ]

    # Create a regex pattern that looks for these hobbies in the text
    pattern = r'\b(' + '|'.join(hobby_list) + r')\b'

    # Use the pattern to find matches in the text
    matches = re.findall(pattern, doc.text, re.IGNORECASE)
    
    return matches

hobbies = extract_hobbies(d)
print(hobbies)
# Out:
# []

# %%
hobbies = [extract_hobbies(d) for d in ep.docs]
hobbies = [h for h in hobbies if h != []]
tmp = pd.Series(hobbies)
hobby_df = pd.concat([
    tmp.explode().value_counts(),
    tmp.apply(set).explode().value_counts()
], axis=1
         ).rename({
    0: 'ent_count',
    1: 'doc_count'
         },
axis=1)
hobby_df
# Out:
#                 ent_count  doc_count
# writing                23         19
# acting                 20         17
# music                  17         14
# fashion                16         12
# running                15         13
# reading                15         14
# football               14          6
# dancing                13         10
# magic                  10          9
# Pottery                10          2
# makeup                  8          7
# theatre                 7          7
# singing                 7          7
# cooking                 6          6
# basketball              6          5
# sports                  5          5
# skiing                  5          3
# soccer                  4          4
# golf                    4          4
# drawing                 3          3
# rugby                   3          1
# poker                   3          2
# sailing                 3          2
# Sports                  2          2
# fishing                 2          2
# swimming                2          1
# tennis                  2          2
# yoga                    1          1
# Singing                 1          1
# cinema                  1          1
# Magic                   1          1
# baking                  1          1
# traveling               1          1
# Football                1          1
# Music                   1          1
# knitting                1          1
# collecting              1          1
# comedy                  1          1
# photography             1          1
# Cooking                 1          1
# playing guitar          1          1
# painting                1          1
# Theatre                 1          1
# Writing                 1          1
# Rugby                   1          1

# %%
hobby_df['ratio'] = hobby_df['ent_count'] / hobby_df['doc_count']
hobby_df
# Out:
#                 ent_count  doc_count     ratio
# writing                23         19  1.210526
# acting                 20         17  1.176471
# music                  17         14  1.214286
# fashion                16         12  1.333333
# running                15         13  1.153846
# reading                15         14  1.071429
# football               14          6  2.333333
# dancing                13         10  1.300000
# magic                  10          9  1.111111
# Pottery                10          2  5.000000
# makeup                  8          7  1.142857
# theatre                 7          7  1.000000
# singing                 7          7  1.000000
# cooking                 6          6  1.000000
# basketball              6          5  1.200000
# sports                  5          5  1.000000
# skiing                  5          3  1.666667
# soccer                  4          4  1.000000
# golf                    4          4  1.000000
# drawing                 3          3  1.000000
# rugby                   3          1  3.000000
# poker                   3          2  1.500000
# sailing                 3          2  1.500000
# Sports                  2          2  1.000000
# fishing                 2          2  1.000000
# swimming                2          1  2.000000
# tennis                  2          2  1.000000
# yoga                    1          1  1.000000
# Singing                 1          1  1.000000
# cinema                  1          1  1.000000
# Magic                   1          1  1.000000
# baking                  1          1  1.000000
# traveling               1          1  1.000000
# Football                1          1  1.000000
# Music                   1          1  1.000000
# knitting                1          1  1.000000
# collecting              1          1  1.000000
# comedy                  1          1  1.000000
# photography             1          1  1.000000
# Cooking                 1          1  1.000000
# playing guitar          1          1  1.000000
# painting                1          1  1.000000
# Theatre                 1          1  1.000000
# Writing                 1          1  1.000000
# Rugby                   1          1  1.000000

# %%
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting', 'acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['dancing', 'dancing'],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  ['cinema'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  ['fashion', 'fashion'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['basketball', 'basketball'],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  [],
#  [],
#  [],
#  ['yoga'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['skiing', 'skiing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing'],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Pottery', 'Pottery', 'Pottery', 'Pottery'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['sailing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Singing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Pottery', 'Pottery', 'Pottery', 'Pottery', 'Pottery', 'Pottery'],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fishing'],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['basketball', 'Sports'],
#  ['makeup'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['golf'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['golf'],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['makeup'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['dancing', 'dancing'],
#  [],
#  ['dancing', 'dancing'],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['basketball'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['poker'],
#  [],
#  ['writing', 'writing'],
#  [],
#  ['drawing'],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['makeup'],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  ['singing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing', 'writing', 'writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['drawing'],
#  ['fashion'],
#  [],
#  [],
#  [],
#  [],
#  ['magic', 'magic'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['magic'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['theatre'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing'],
#  [],
#  [],
#  ['football', 'football', 'football', 'running', 'football'],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fashion'],
#  ['football', 'football'],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['fashion'],
#  ['sports'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['football'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['football'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['running', 'running'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing', 'music', 'music', 'music', 'music', 'cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  ['poker', 'poker'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['makeup', 'soccer'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cooking'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Sports', 'sports'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['singing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['soccer'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['acting'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['reading', 'reading'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['music'],
#  [],
#  [],
#  ['cooking'],
#  [],
#  [],
#  [],
#  [],
#  ['fashion'],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  ['writing'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]
