# %%
print('kernel_on')
# Out:
# kernel_on

# %% [markdown]
# # Exploratory Analysis on DialogRE:
# - **Objective**: Analyze dialogue relations data from JSON files
# - **Process**: Convert data to DataFrame, flatten Relations column, and extract `relation_type`
# - **Analysis**: Study distribution of `relation_type`, with a special focus on excluding `no_relation`

# %%
from src.paths import LOCAL_PROCESSED_DATA_PATH
from src.statistics import get_pct_value_counts
import pandas as pd
import json
from pathlib import Path
import glob

# Get a list of all json files in the directory, excluding 'dev'
files = [Path(f) for f in glob.glob(str(LOCAL_PROCESSED_DATA_PATH / "dialog-re-fixed-relations/*.json"))]


# Create an empty DataFrame
df1 = pd.DataFrame(columns=["Dialogue", "Relations", "Origin"])

# Loop over all json files in the directory (except for dev.json)
for file_name in files:
    with open(file_name, 'r') as file:
        data = json.load(file)

        # Convert the data to a DataFrame
        df_temp = pd.DataFrame(data, columns=["Dialogue", "Relations"])

        # Add a new column to this DataFrame for the origin
        df_temp["Origin"] = file_name.stem  # This will get just the file name without the extension

        # Append the temporary DataFrame to the main DataFrame
        df1 = pd.concat([df1, df_temp], ignore_index=True)
df1
# Out:
#                                                Dialogue  \
# 0     [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# 1     [Speaker 1, Speaker 2: Hi, Speaker 3: Hi! Hey ...
# 2     [Speaker 1, Speaker 2: Hi!, Speaker 3: Hey!, S...
# 3     [Speaker 1: Wow! It looks like we got a lot of...
# 4     [Speaker 1: Now, Mom, everything's going fine,...
# ...                                                 ...
# 1783  [Speaker 1: Nice camoflauge man, for a minute ...
# 1784  [Speaker 1: Well, I'm sure you'll teach her a ...
# 1785  [Speaker 1: You know what? I can't even worry ...
# 1786  [Speaker 1: And cut. Hey, Butt Guy, what the h...
# 1787  [Speaker 1: Buon Giorno, Bella Phoebe!, Speake...
#
#                                               Relations Origin
# 0     [{'y': 'casting director', 'x': 'Ann', 'rid': ...    dev
# 1     [{'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [...    dev
# 2     [{'y': 'man', 'x': 'Speaker 4', 'rid': [37], '...    dev
# 3     [{'y': 'baby', 'x': 'Speaker 2', 'rid': [37], ...    dev
# 4     [{'y': '26', 'x': 'Speaker 1', 'rid': [25], 'r...    dev
# ...                                                 ...    ...
# 1783  [{'y': 'Speaker 1', 'x': 'Speaker 2', 'rid': [...  train
# 1784  [{'y': 'Sir', 'x': 'Speaker 1', 'rid': [37], '...  train
# 1785  [{'y': 'baby', 'x': 'Speaker 1', 'rid': [37], ...  train
# 1786  [{'y': 'Butt Guy', 'x': 'Speaker 2', 'rid': [3...  train
# 1787  [{'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [...  train
#
# [1788 rows x 3 columns]

# %%
get_pct_value_counts(df1.Origin)
# Out:
#         count  proportion
# Origin
# train    1073    0.600112
# dev       358    0.200224
# test      357    0.199664

# %%
# import necessary modules
import pandas as pd
from itertools import chain

# assuming df1 is your DataFrame

# flatten Relations column
relations = df1['Relations'].apply(pd.Series).stack().reset_index(drop=True)

# create new dataframe
df2 = pd.DataFrame({'Relations': relations})

# extract 'relation_type' from dictionary and add it as a new column in df2
df2['relation_type'] = df2['Relations'].apply(lambda x: x['r'][0])

# drop the 'Relations' column
df2 = df2.drop('Relations', axis=1)

# Now, we can count the amount of each 'relation_type'
relation_stats = get_pct_value_counts(df2['relation_type'])

relation_stats
# Out:
#                            count  proportion
# relation_type
# no_relation                16489    0.628440
# per:alternate_names         2136    0.081409
# unanswerable                2099    0.079998
# per:girl/boyfriend           736    0.028051
# per:positive_impression      657    0.025040
# per:friends                  648    0.024697
# per:title                    414    0.015779
# per:spouse                   316    0.012044
# per:siblings                 303    0.011548
# per:parents                  270    0.010290
# per:children                 266    0.010138
# per:negative_impression      222    0.008461
# per:roommate                 193    0.007356
# per:alumni                   152    0.005793
# per:other_family             120    0.004574
# gpe:visitors_of_place         92    0.003506
# per:visited_place             92    0.003506
# per:works                     89    0.003392
# per:client                    87    0.003316
# gpe:residents_of_place        84    0.003201
# per:place_of_residence        84    0.003201
# per:age                       78    0.002973
# per:boss                      72    0.002744
# per:employee_or_member_of     72    0.002744
# org:employees_or_members      72    0.002744
# per:place_of_work             71    0.002706
# per:acquaintance              66    0.002515
# per:subordinate               63    0.002401
# per:neighbor                  56    0.002134
# per:pet                       48    0.001829
# per:dates                     35    0.001334
# per:origin                    26    0.000991
# per:schools_attended           8    0.000305
# org:students                   8    0.000305
# per:major                      6    0.000229
# per:date_of_birth              6    0.000229
# gpe:births_in_place            1    0.000038
# per:place_of_birth             1    0.000038

# %%
mask = df2.relation_type != 'no_relation'
relation_stats_original = get_pct_value_counts(df2['relation_type'][mask])
relation_stats_original
# Out:
#                            count  proportion
# relation_type
# per:alternate_names         2136    0.219099
# unanswerable                2099    0.215304
# per:girl/boyfriend           736    0.075495
# per:positive_impression      657    0.067392
# per:friends                  648    0.066468
# per:title                    414    0.042466
# per:spouse                   316    0.032414
# per:siblings                 303    0.031080
# per:parents                  270    0.027695
# per:children                 266    0.027285
# per:negative_impression      222    0.022772
# per:roommate                 193    0.019797
# per:alumni                   152    0.015591
# per:other_family             120    0.012309
# gpe:visitors_of_place         92    0.009437
# per:visited_place             92    0.009437
# per:works                     89    0.009129
# per:client                    87    0.008924
# gpe:residents_of_place        84    0.008616
# per:place_of_residence        84    0.008616
# per:age                       78    0.008001
# per:boss                      72    0.007385
# per:employee_or_member_of     72    0.007385
# org:employees_or_members      72    0.007385
# per:place_of_work             71    0.007283
# per:acquaintance              66    0.006770
# per:subordinate               63    0.006462
# per:neighbor                  56    0.005744
# per:pet                       48    0.004924
# per:dates                     35    0.003590
# per:origin                    26    0.002667
# per:schools_attended           8    0.000821
# org:students                   8    0.000821
# per:major                      6    0.000615
# per:date_of_birth              6    0.000615
# gpe:births_in_place            1    0.000103
# per:place_of_birth             1    0.000103

# %%
df1['char_count'] = df1.apply(lambda x: len(f"{x.Dialogue},{x.Relations}"), axis=1)

df1
# Out:
#                                                Dialogue  \
# 0     [Speaker 1: Hey!, Speaker 2: Hey., Speaker 3: ...
# 1     [Speaker 1, Speaker 2: Hi, Speaker 3: Hi! Hey ...
# 2     [Speaker 1, Speaker 2: Hi!, Speaker 3: Hey!, S...
# 3     [Speaker 1: Wow! It looks like we got a lot of...
# 4     [Speaker 1: Now, Mom, everything's going fine,...
# ...                                                 ...
# 1783  [Speaker 1: Nice camoflauge man, for a minute ...
# 1784  [Speaker 1: Well, I'm sure you'll teach her a ...
# 1785  [Speaker 1: You know what? I can't even worry ...
# 1786  [Speaker 1: And cut. Hey, Butt Guy, what the h...
# 1787  [Speaker 1: Buon Giorno, Bella Phoebe!, Speake...
#
#                                               Relations Origin  char_count
# 0     [{'y': 'casting director', 'x': 'Ann', 'rid': ...    dev        9235
# 1     [{'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [...    dev        2195
# 2     [{'y': 'man', 'x': 'Speaker 4', 'rid': [37], '...    dev        8808
# 3     [{'y': 'baby', 'x': 'Speaker 2', 'rid': [37], ...    dev        1959
# 4     [{'y': '26', 'x': 'Speaker 1', 'rid': [25], 'r...    dev         964
# ...                                                 ...    ...         ...
# 1783  [{'y': 'Speaker 1', 'x': 'Speaker 2', 'rid': [...  train        2660
# 1784  [{'y': 'Sir', 'x': 'Speaker 1', 'rid': [37], '...  train        1984
# 1785  [{'y': 'baby', 'x': 'Speaker 1', 'rid': [37], ...  train        1437
# 1786  [{'y': 'Butt Guy', 'x': 'Speaker 2', 'rid': [3...  train         655
# 1787  [{'y': 'Speaker 2', 'x': 'Speaker 1', 'rid': [...  train        1907
#
# [1788 rows x 4 columns]

# %%
df1.plot(y='char_count', kind='box')

# %%
stats = df1['char_count'].describe()
stats
# Out:
# count     1788.000000
# mean      2661.460291
# std       2044.283050
# min        211.000000
# 25%       1310.750000
# 50%       2109.500000
# 75%       3381.250000
# max      18144.000000
# Name: char_count, dtype: float64

# %%
stats = df1['char_count'].describe()
mean_character_count = stats['mean']
average_tokens = mean_character_count / 5
total_tokens = average_tokens * 1000

# Cost calculation
cost_per_token = 0.0015  # Cost per token for 4K context (ChatGPT)
estimated_cost = total_tokens * cost_per_token

# Display the estimated cost
print(f"The estimated cost for synthesizing 1000 samples of data is ${estimated_cost:.2f}")
# Out:
# The estimated cost for synthesizing 1000 samples of data is $0.00

# %% [markdown]
# `Conclusion`: Class imbalance is a problem that should be tackled.
